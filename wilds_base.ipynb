# %%
# %load_ext autoreload
# %autoreload 2
# Set-up: Import numpy and assign GPU


import os
os.environ['TRANSFORMERS_CACHE'] = '/local/helenl/.cache/'
os.environ['PYTORCH_TRANSFORMERS_CACHE'] = '/local/helenl/.cache/'

import numpy as np
import scipy as sp
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from tqdm.notebook import tqdm

from gpu_utils import restrict_GPU_pytorch
from helenl_utils import *

restrict_GPU_pytorch('1')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Using GPU:1

# %%
# Load Amazon WILDS pre-trained model

import statistics
import sys
import pickle
import numpy as np
import pandas as pd
import statistics


import torch
import torchvision.transforms as transforms

import argparse
import pdb


from wordcloud import WordCloud

# %%
# TO SEE THE AMAZON CONFIG, RUN THIS:

# Grab config generated by WILDS library from txt file
infile = open('./model_configs/amazon_ERM_config.txt','rb')
new_dict = vars(pickle.load(infile))
infile.close() 

# Create config with ERM algorithm
config = Namespace(**new_dict)

new_dict
# Out:
# {'dataset': 'amazon',
#  'algorithm': 'ERM',
#  'root_dir': '../datasets',
#  'split_scheme': 'official',
#  'dataset_kwargs': {},
#  'download': False,
#  'frac': 1.0,
#  'version': None,
#  'loader_kwargs': {'num_workers': 1, 'pin_memory': True},
#  'train_loader': 'standard',
#  'uniform_over_groups': False,
#  'distinct_groups': None,
#  'n_groups_per_batch': 2,
#  'batch_size': 8,
#  'eval_loader': 'standard',
#  'model': 'distilbert-base-uncased',
#  'model_kwargs': {},
#  'transform': 'bert',
#  'target_resolution': None,
#  'resize_scale': None,
#  'max_token_length': 512,
#  'loss_function': 'cross_entropy',
#  'loss_kwargs': {},
#  'groupby_fields': ['user'],
#  'group_dro_step_size': None,
#  'coral_penalty_weight': 1.0,
#  'irm_lambda': 1.0,
#  'irm_penalty_anneal_iters': None,
#  'algo_log_metric': 'accuracy',
#  'val_metric': '10th_percentile_acc',
#  'val_metric_decreasing': False,
#  'n_epochs': 3,
#  'optimizer': 'AdamW',
#  'lr': 1e-05,
#  'weight_decay': 0.01,
#  'max_grad_norm': 1.0,
#  'optimizer_kwargs': {},
#  'scheduler': 'linear_schedule_with_warmup',
#  'scheduler_kwargs': {'num_warmup_steps': 0},
#  'scheduler_metric_split': 'val',
#  'scheduler_metric_name': None,
#  'process_outputs_function': 'multiclass_logits_to_pred',
#  'evaluate_all_splits': True,
#  'eval_splits': [],
#  'eval_only': False,
#  'eval_epoch': None,
#  'device': 0,
#  'seed': 0,
#  'log_dir': './logs',
#  'log_every': 50,
#  'save_step': None,
#  'save_best': True,
#  'save_last': True,
#  'save_pred': True,
#  'no_group_logging': True,
#  'use_wandb': False,
#  'progress_bar': False,
#  'resume': False}

# %%
completed_augment_labels = ['bert'
                           , 'nlp_ocr'
                           , 'nlp_keyboard'
                           , 'nlp_random_char_insert'
                           , 'nlp_random_char_substitution'
                           , 'nlp_random_char_swap'
                           , 'nlp_random_char_deletion'
                           #, 'nlp_spelling_substitution'
                           , 'nlp_random_word_swap'
                           , 'nlp_random_word_delete'
                           , 'nlp_random_word_substitute'
                           , 'nlp_wordnet_synonym'
                           , 'nlp_ppdb_synonym'
                           , 'nlp_antonym'
                           , 'nlp_random_contextual_word_insertion_bert_uncased_embedding'
                           , 'nlp_random_contextual_word_insertion_bert_cased_embedding'
                           , 'nlp_random_contextual_word_insertion_distilbert_uncased_embedding'
                           , 'nlp_random_contextual_word_insertion_distilbert_cased_embedding'
                           , 'nlp_random_contextual_word_insertion_roberta_base_embedding'
                           , 'nlp_random_contextual_word_insertion_distilroberta_base_embedding'
                           , 'nlp_random_contextual_word_insertion_bart_base_embedding'
                           , 'nlp_random_contextual_word_insertion_squeezebert_uncased_embedding'
                           , 'nlp_random_contextual_word_substitution_bert_uncased_embedding'
                           , 'nlp_random_contextual_word_substitution_bert_cased_embedding'
                           , 'nlp_random_contextual_word_substitution_distilbert_uncased_embedding'
                           , 'nlp_random_contextual_word_substitution_distilbert_cased_embedding'
                           , 'nlp_random_contextual_word_substitution_roberta_embedding'
                           , 'nlp_random_contextual_word_substitution_distilroberta_base_embedding'
                           , 'nlp_random_contextual_word_substitution_bart_base_embedding'
                           , 'nlp_random_contextual_word_substitution_squeezebert_uncased_embedding'
                           , 'nlp_contextual_sentence_insertion_gpt2_embedding'
                           , 'nlp_contextual_sentence_insertion_xlnet_cased_embedding'
                           , 'nlp_contextual_sentence_insertion_distilgpt2_embedding'
                           , 'nlp_abstractive_summarization_bart_large_cnn'
                           , 'nlp_abstractive_summarization_t5_small'
                           , 'nlp_abstractive_summarization_t5_base'
                           , 'nlp_abstractive_summarization_t5_large'

                           ]

in_progress = ['nlp_random_crop'
               , 'nlp_random_token_split'
               , 'nlp_back_translation_aug'
              ]


word_augmentations = [#'nlp_random_word_swap'
                           #, 'nlp_random_word_delete'
                           #, 'nlp_random_word_substitute'
                           #, 'nlp_wordnet_synonym'
                           #, 'nlp_ppdb_synonym'
                           #, 'nlp_antonym'
                           'nlp_random_contextual_word_insertion_bert_uncased_embedding'
                           , 'nlp_random_contextual_word_insertion_bert_cased_embedding'
                           , 'nlp_random_contextual_word_insertion_distilbert_uncased_embedding'
                           , 'nlp_random_contextual_word_insertion_distilbert_cased_embedding'
                           , 'nlp_random_contextual_word_insertion_roberta_base_embedding'
                           , 'nlp_random_contextual_word_insertion_distilroberta_base_embedding'
                           , 'nlp_random_contextual_word_insertion_bart_base_embedding'
                           , 'nlp_random_contextual_word_insertion_squeezebert_uncased_embedding'
                           , 'nlp_random_contextual_word_substitution_bert_uncased_embedding'
                           , 'nlp_random_contextual_word_substitution_bert_cased_embedding'
                           , 'nlp_random_contextual_word_substitution_distilbert_uncased_embedding'
                           , 'nlp_random_contextual_word_substitution_distilbert_cased_embedding'
                           , 'nlp_random_contextual_word_substitution_roberta_embedding'
                           , 'nlp_random_contextual_word_substitution_distilroberta_base_embedding'
                           , 'nlp_random_contextual_word_substitution_bart_base_embedding'
                           , 'nlp_random_contextual_word_substitution_squeezebert_uncased_embedding'
    
]


char_augmentations = ['bert'
                           , 'nlp_ocr'
                           , 'nlp_keyboard'
                           , 'nlp_random_char_insert'
                           , 'nlp_random_char_substitution'
                           , 'nlp_random_char_swap'
                           , 'nlp_random_char_deletion'
                           , 'nlp_spelling_substitution']

# %%
full_dataset = get_dataset(dataset="civilcomments", download=False, root_dir = './wilds/data')

# %%
full_dataset = get_dataset(dataset="amazon", download=False, root_dir = './wilds/data')

# %%
predict_augmented_labels('nlp_ocr'
                             , "amazon"
                             , "ERM"
                             , "/data/ddmg/prism/tta/outputs/amazon_ERM_predictions_optimized_params/raw/"
                             , full_dataset = full_dataset
                            , num_samples = 1
                            , aug_char_min = 1
                            , aug_char_max = 1
                            , aug_char_p = 0.1
                            , aug_word_min = 1
                            , aug_word_max = None
                            , aug_word_p = 0.1
                            , min_char = 4)
# Out:
# num_samples: 1
# char_min: 1
# word_p: 0.1
# char_min: 1
# word_p: 0.1
# nlp_ocr
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.weight', 'pre_classifier.weight', 'classifier.bias', 'pre_classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/12507 [00:00<?, ?it/s]
# 100050
# 100050
# 100050
# (array([     11,      31,      51, ..., 4002112, 4002145, 4002163]),
#  <wilds.datasets.amazon_dataset.AmazonDataset at 0x7f3aa55fc710>)

# %%
for word_aug in word_augmentations:
    print(word_aug)
    predict_augmented_labels(word_aug
                             , "civilcomments"
                             , "ERM"
                             , "./data/civilcomments_ERM_predictions_optimized_params_four_samples"
                             , full_dataset = full_dataset
                            , num_samples = 4
                            , aug_char_min = 1
                            , aug_char_max = 1
                            , aug_char_p = 1
                            , aug_word_min = 1
                            , aug_word_max = 1
                            , aug_word_p = 1
                            , min_char = 4)

# %%
for char_aug in char_augmentations:
    print(char_aug)
    predict_augmented_labels(char_aug
                             , "civilcomments"
                             , "ERM"
                             , "./data/civilcomments_ERM_predictions_optimized_params_four_samples"
                             , full_dataset
                            , num_samples = 4
                            , aug_char_min = 1
                            , aug_char_max = 1
                            , aug_char_p = 1
                            , aug_word_min = 1
                            , aug_word_max = None
                            , aug_word_p = 0.1
                            , min_char = 4)

# %%
predict_augmented_labels('nlp_random_contextual_word_insertion_bert_uncased_embedding'
                        , num_samples = 1
                            , aug_word_min = 1
                            , aug_word_max = 1
                            , aug_word_p = 1)
# Out:
# num_samples: 1
# char_min: 1
# word_p: 1
# char_min: 1
# word_p: 1
# nlp_random_contextual_word_insertion_bert_uncased_embedding
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_projector.weight', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_layer_norm.bias']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'classifier.bias', 'pre_classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# (array([     0,     10,     11, ..., 447989, 447993, 447997]),
#  <wilds.datasets.civilcomments_dataset.CivilCommentsDataset at 0x7f51a1a982e8>)

# %%
import nlpaug
print(nlpaug.__version__)
# Out:
# 1.1.7

# %%
sentence_augmentations = [#'nlp_random_sentence_shuffle_left'
                          #, 'nlp_random_sentence_shuffle_right'
                          #, 'nlp_random_sentence_shuffle_neighbor'
                          #, 'nlp_random_sentence_shuffle_random'
                         # 'nlp_contextual_sentence_insertion_gpt2_embedding'
                          #'nlp_contextual_sentence_insertion_xlnet_cased_embedding'
                          #, 'nlp_contextual_sentence_insertion_distilgpt2_embedding'
                          'nlp_abstractive_summarization_bart_large_cnn'
                          , 'nlp_abstractive_summarization_t5_small'
                          , 'nlp_abstractive_summarization_t5_base'
                          , 'nlp_abstractive_summarization_t5_large'
]


full_dataset = get_dataset(dataset="civilcomments", download=False, root_dir = './wilds/data')


for sentence_aug in sentence_augmentations:
    print(sentence_aug)
    predict_augmented_labels(sentence_aug
                             , "civilcomments"
                             , "ERM"
                             , "./data/civilcomments_ERM_predictions_optimized_params/raw/"
                             , full_dataset = full_dataset
                            , num_samples = 1
                            , aug_sentence_min = 1
                            , aug_sentence_max = 1
                            , aug_sentence_p = 1)
    

for sentence_aug in sentence_augmentations:
    print(sentence_aug)
    predict_augmented_labels(sentence_aug
                             , "civilcomments"
                             , "ERM"
                             , "./data/civilcomments_ERM_predictions_optimized_params_four_samples/raw/"
                             , full_dataset = full_dataset
                            , num_samples = 4
                            , aug_sentence_min = 1
                            , aug_sentence_max = 1
                            , aug_sentence_p = 1)
# Out:
# nlp_abstractive_summarization_bart_large_cnn
# num_samples: 1
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/483 [00:00<?, ?B/s]
# char_min: 1
# word_p: 0.1
# char_min: 1
# word_p: 0.1
# nlp_abstractive_summarization_bart_large_cnn
# initialize model
# ERM
# Downloading:   0%|          | 0.00/256M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_projector.weight', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_transform.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.weight', 'pre_classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.51G [00:00<?, ?B/s]
# Your max_length is set to 50, but you input_length is only 30. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 50, but you input_length is only 14. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
# Your max_length is set to 50, but you input_length is only 35. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=17)
# Your max_length is set to 50, but you input_length is only 17. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
# Your max_length is set to 50, but you input_length is only 30. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 50, but you input_length is only 25. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
# Your max_length is set to 50, but you input_length is only 6. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 50, but you input_length is only 14. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
# Your max_length is set to 50, but you input_length is only 16. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
# Your max_length is set to 50, but you input_length is only 28. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=14)
# Your max_length is set to 50, but you input_length is only 34. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=17)
# Your max_length is set to 50, but you input_length is only 33. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
# Your max_length is set to 50, but you input_length is only 42. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
# Your max_length is set to 50, but you input_length is only 38. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
# Your max_length is set to 50, but you input_length is only 17. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
# Your max_length is set to 50, but you input_length is only 32. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
# Your max_length is set to 50, but you input_length is only 36. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=18)
# Your max_length is set to 50, but you input_length is only 20. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=10)
# Your max_length is set to 50, but you input_length is only 38. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
# Your max_length is set to 50, but you input_length is only 33. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
# Your max_length is set to 50, but you input_length is only 7. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 50, but you input_length is only 10. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=5)
# Your max_length is set to 50, but you input_length is only 13. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=6)
# Your max_length is set to 50, but you input_length is only 7. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 50, but you input_length is only 25. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
# Your max_length is set to 50, but you input_length is only 12. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=6)
# Your max_length is set to 50, but you input_length is only 29. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=14)
# Your max_length is set to 50, but you input_length is only 41. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# Your max_length is set to 50, but you input_length is only 20. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=10)
# Your max_length is set to 50, but you input_length is only 29. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=14)
# Your max_length is set to 50, but you input_length is only 34. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=17)
# Your max_length is set to 50, but you input_length is only 23. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=11)
# Your max_length is set to 50, but you input_length is only 46. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=23)
# Your max_length is set to 50, but you input_length is only 21. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=10)
# Your max_length is set to 50, but you input_length is only 43. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
# Your max_length is set to 50, but you input_length is only 19. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=9)
# Your max_length is set to 50, but you input_length is only 29. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=14)
# Your max_length is set to 50, but you input_length is only 24. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
# Your max_length is set to 50, but you input_length is only 21. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=10)
# Your max_length is set to 50, but you input_length is only 9. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=4)
# Your max_length is set to 50, but you input_length is only 48. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 50, but you input_length is only 16. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
# Your max_length is set to 50, but you input_length is only 19. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=9)
# Your max_length is set to 50, but you input_length is only 38. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
# Your max_length is set to 50, but you input_length is only 28. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=14)
# Your max_length is set to 50, but you input_length is only 21. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=10)
# Your max_length is set to 50, but you input_length is only 27. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
# Your max_length is set to 50, but you input_length is only 20. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=10)
# Your max_length is set to 50, but you input_length is only 29. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=14)
# Your max_length is set to 50, but you input_length is only 44. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Your max_length is set to 50, but you input_length is only 30. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 50, but you input_length is only 41. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-17db01e4c3bb> in <module>
#      26                             , aug_sentence_min = 1
#      27                             , aug_sentence_max = 1
# ---> 28                             , aug_sentence_p = 1)
#      29
#      30
#
# /mnt/hdd/home/helenl/helenl/tta_research/helenl_utils.py in predict_augmented_labels(transform_name, dataset_name, algorithm_name, saved_file_dir, full_dataset, num_samples, aug_char_min, aug_char_max, aug_char_p, aug_word_min, aug_word_max, aug_word_p, aug_sentence_min, aug_sentence_max, aug_sentence_p, min_char)
#     254     metadata = []
#     255
# --> 256     for batch in tqdm(it):
#     257
#     258         for sample in batch[0]:
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/tqdm/notebook.py in __iter__(self)
#     255     def __iter__(self):
#     256         try:
# --> 257             for obj in super(tqdm_notebook, self).__iter__():
#     258                 # return super(tqdm...) will not catch exception
#     259                 yield obj
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/tqdm/std.py in __iter__(self)
#    1178
#    1179         try:
# -> 1180             for obj in iterable:
#    1181                 yield obj
#    1182                 # Update and possibly print the progressbar.
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/wilds/datasets/wilds_dataset.py in __getitem__(self, idx)
#     501                 x, y = self.transform(x, y)
#     502             else:
# --> 503                 x = self.transform(x)
#     504         return x, y, metadata
#     505
#
# /mnt/hdd/home/helenl/helenl/tta_research/transforms_helenl.py in transform(text)
#     506
#     507
# --> 508             text = aug(text, n = num_samples)
#     509
#     510         else:
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/nlpaug/base_augmenter.py in augment(self, data, n, num_thread)
#      93             elif self.__class__.__name__ in ['AbstSummAug', 'BackTranslationAug', 'ContextualWordEmbsAug', 'ContextualWordEmbsForSentenceAug']:
#      94                 for _ in range(aug_num):
# ---> 95                     result = action_fx(clean_data)
#      96                     if isinstance(result, list):
#      97                         augmented_results.extend(result)
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/nlpaug/augmenter/sentence/abst_summ.py in substitute(self, data)
#      82             all_data = [data]
#      83
# ---> 84         return self.model.predict(all_data)
#      85
#      86     @classmethod
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/nlpaug/model/lang_models/summarization_transformers.py in predict(self, texts, target_words, n)
#      52                     temperature=self.temperature,
#      53                     top_k=self.top_k,
# ---> 54                     top_p=self.top_p)
#      55                 if isinstance(predict_result, list):
#      56                     results.extend(predict_result)
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/pipelines/text2text_generation.py in __call__(self, *args, **kwargs)
#     223               The token ids of the summary.
#     224         """
# --> 225         return super().__call__(*args, **kwargs)
#     226
#     227     def check_inputs(self, input_length: int, min_length: int, max_length: int) -> bool:
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/pipelines/text2text_generation.py in __call__(self, *args, **kwargs)
#     135         """
#     136
# --> 137         result = super().__call__(*args, **kwargs)
#     138         if isinstance(result, dict):
#     139             return [result]
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1082                     inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1083                 )
# -> 1084                 outputs = [output for output in final_iterator]
#    1085                 return outputs
#    1086             else:
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/pipelines/base.py in <listcomp>(.0)
#    1082                     inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1083                 )
# -> 1084                 outputs = [output for output in final_iterator]
#    1085                 return outputs
#    1086             else:
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/pipelines/base.py in __next__(self)
#     766                 return self.loader_batch_item()
#     767
# --> 768             item = next(self.iterator)
#     769             processed = self.infer(item, **self.params)
#     770             if self.loader_batch_size is not None:
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/pipelines/base.py in __next__(self)
#     767
#     768             item = next(self.iterator)
# --> 769             processed = self.infer(item, **self.params)
#     770             if self.loader_batch_size is not None:
#     771                 if isinstance(processed, torch.Tensor):
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1032                 with inference_context():
#    1033                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1034                     model_outputs = self._forward(model_inputs, **forward_params)
#    1035                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1036             else:
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/pipelines/text2text_generation.py in _forward(self, model_inputs, **generate_kwargs)
#     153         generate_kwargs["max_length"] = generate_kwargs.get("max_length", self.model.config.max_length)
#     154         self.check_inputs(input_length, generate_kwargs["min_length"], generate_kwargs["max_length"])
# --> 155         output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     156         return {"output_ids": output_ids}
#     157
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/generation_utils.py in generate(self, inputs, max_length, min_length, do_sample, early_stopping, num_beams, temperature, top_k, top_p, repetition_penalty, bad_words_ids, bos_token_id, pad_token_id, eos_token_id, length_penalty, no_repeat_ngram_size, encoder_no_repeat_ngram_size, num_return_sequences, max_time, max_new_tokens, decoder_start_token_id, use_cache, num_beam_groups, diversity_penalty, prefix_allowed_tokens_fn, logits_processor, stopping_criteria, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, forced_bos_token_id, forced_eos_token_id, remove_invalid_values, synced_gpus, **model_kwargs)
#    1178                 return_dict_in_generate=return_dict_in_generate,
#    1179                 synced_gpus=synced_gpus,
# -> 1180                 **model_kwargs,
#    1181             )
#    1182
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/generation_utils.py in beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    1909                 return_dict=True,
#    1910                 output_attentions=output_attentions,
# -> 1911                 output_hidden_states=output_hidden_states,
#    1912             )
#    1913
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/models/bart/modeling_bart.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1333             output_attentions=output_attentions,
#    1334             output_hidden_states=output_hidden_states,
# -> 1335             return_dict=return_dict,
#    1336         )
#    1337         lm_logits = self.lm_head(outputs[0]) + self.final_logits_bias
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/models/bart/modeling_bart.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1221             output_attentions=output_attentions,
#    1222             output_hidden_states=output_hidden_states,
# -> 1223             return_dict=return_dict,
#    1224         )
#    1225
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/models/bart/modeling_bart.py in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1079                     past_key_value=past_key_value,
#    1080                     output_attentions=output_attentions,
# -> 1081                     use_cache=use_cache,
#    1082                 )
#    1083             hidden_states = layer_outputs[0]
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/models/bart/modeling_bart.py in forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     435         # Fully Connected
#     436         residual = hidden_states
# --> 437         hidden_states = self.activation_fn(self.fc1(hidden_states))
#     438         hidden_states = nn.functional.dropout(hidden_states, p=self.activation_dropout, training=self.training)
#     439         hidden_states = self.fc2(hidden_states)
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      94
#      95     def forward(self, input: Tensor) -> Tensor:
# ---> 96         return F.linear(input, self.weight, self.bias)
#      97
#      98     def extra_repr(self) -> str:
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1845     if has_torch_function_variadic(input, weight):
#    1846         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1847     return torch._C._nn.linear(input, weight, bias)
#    1848
#    1849
#
# KeyboardInterrupt:

# %%
import nlpaug.augmenter.sentence as nas

text = "The quick brown fox jumped over the lazy dog."

aug = nas.ContextualWordEmbsForSentenceAug(model_path='gpt2')
augmented_text = aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-9cefa2ea0b41> in <module>
#       4
#       5 aug = nas.ContextualWordEmbsForSentenceAug(model_path='gpt2')
# ----> 6 augmented_text = aug.augment(text)
#       7 print("Original:")
#       8 print(text)
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/nlpaug/base_augmenter.py in augment(self, data, n, num_thread)
#      93             elif self.__class__.__name__ in ['AbstSummAug', 'BackTranslationAug', 'ContextualWordEmbsAug', 'ContextualWordEmbsForSentenceAug']:
#      94                 for _ in range(aug_num):
# ---> 95                     result = action_fx(clean_data)
#      96                     if isinstance(result, list):
#      97                         augmented_results.extend(result)
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/nlpaug/augmenter/sentence/context_word_embs_sentence.py in insert(self, data)
#      96             all_data = [data]
#      97
# ---> 98         return self.model.predict(all_data)
#      99
#     100     @classmethod
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/nlpaug/model/lang_models/text_generation_transformers.py in predict(self, texts, target_words, n)
#      80                     top_p=self.top_p,
#      81                     do_sample=True,
# ---> 82                     num_return_sequences=1,
#      83                 )
#      84                 if isinstance(predict_result, list):
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     169               -- The token ids of the generated text.
#     170         """
# --> 171         return super().__call__(text_inputs, **kwargs)
#     172
#     173     def preprocess(self, prompt_text, prefix="", handle_long_generation=None, **generate_kwargs):
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1082                     inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1083                 )
# -> 1084                 outputs = [output for output in final_iterator]
#    1085                 return outputs
#    1086             else:
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/pipelines/base.py in <listcomp>(.0)
#    1082                     inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1083                 )
# -> 1084                 outputs = [output for output in final_iterator]
#    1085                 return outputs
#    1086             else:
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/pipelines/base.py in __next__(self)
#     766                 return self.loader_batch_item()
#     767
# --> 768             item = next(self.iterator)
#     769             processed = self.infer(item, **self.params)
#     770             if self.loader_batch_size is not None:
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/pipelines/base.py in __next__(self)
#     767
#     768             item = next(self.iterator)
# --> 769             processed = self.infer(item, **self.params)
#     770             if self.loader_batch_size is not None:
#     771                 if isinstance(processed, torch.Tensor):
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1032                 with inference_context():
#    1033                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1034                     model_outputs = self._forward(model_inputs, **forward_params)
#    1035                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1036             else:
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/pipelines/text_generation.py in _forward(self, model_inputs, **generate_kwargs)
#     204             input_ids = None
#     205         prompt_text = model_inputs.pop("prompt_text")
# --> 206         generated_sequence = self.model.generate(input_ids=input_ids, **generate_kwargs)  # BS x SL
#     207         return {"generated_sequence": generated_sequence, "input_ids": input_ids, "prompt_text": prompt_text}
#     208
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/generation_utils.py in generate(self, inputs, max_length, min_length, do_sample, early_stopping, num_beams, temperature, top_k, top_p, repetition_penalty, bad_words_ids, bos_token_id, pad_token_id, eos_token_id, length_penalty, no_repeat_ngram_size, encoder_no_repeat_ngram_size, num_return_sequences, max_time, max_new_tokens, decoder_start_token_id, use_cache, num_beam_groups, diversity_penalty, prefix_allowed_tokens_fn, logits_processor, stopping_criteria, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, forced_bos_token_id, forced_eos_token_id, remove_invalid_values, synced_gpus, **model_kwargs)
#    1144                 return_dict_in_generate=return_dict_in_generate,
#    1145                 synced_gpus=synced_gpus,
# -> 1146                 **model_kwargs,
#    1147             )
#    1148
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/generation_utils.py in sample(self, input_ids, logits_processor, stopping_criteria, logits_warper, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    1681             # sample
#    1682             probs = nn.functional.softmax(next_token_scores, dim=-1)
# -> 1683             next_tokens = torch.multinomial(probs, num_samples=1).squeeze(1)
#    1684
#    1685             # finished sentences should have their next token be a padding token
#
# RuntimeError: Inplace update to inference tensor outside InferenceMode is not allowed.You can make a clone to get a normal tensor before doing inplace update.See https://github.com/pytorch/rfcs/pull/17 for more details.

# %%
article = """
The history of natural language processing (NLP) generally started in the 1950s, although work can be 
found from earlier periods. In 1950, Alan Turing published an article titled "Computing Machinery and 
Intelligence" which proposed what is now called the Turing test as a criterion of intelligence. 
The Georgetown experiment in 1954 involved fully automatic translation of more than sixty Russian 
sentences into English. The authors claimed that within three or five years, machine translation would
be a solved problem. However, real progress was much slower, and after the ALPAC report in 1966, 
which found that ten-year-long research had failed to fulfill the expectations, funding for machine 
translation was dramatically reduced. Little further research in machine translation was conducted 
until the late 1980s when the first statistical machine translation systems were developed.
"""

aug = nas.AbstSummAug(model_path='t5-base')
augmented_text = aug.augment(article)
print("Original:")
print(article)
print("Augmented Text:")
print(augmented_text)

# %%
amazon_full_dataset = get_dataset(dataset="amazon", download=False, root_dir = './wilds/data')



for word_aug in word_augmentations:
    print(word_aug)
    predict_augmented_labels(word_aug
                             , "amazon"
                             , "ERM"
                             , "./data/amazon_ERM_predictions_optimized_params/"
                             , full_dataset = amazon_full_dataset
                            , num_samples = 1
                            , aug_char_min = 1
                            , aug_char_max = 1
                            , aug_char_p = 1
                            , aug_word_min = 1
                            , aug_word_max = 1
                            , aug_word_p = 1
                            , min_char = 4)
# Out:
# nlp_random_contextual_word_insertion_bert_uncased_embedding
# num_samples: 1
# char_min: 1
# word_p: 1
# char_min: 1
# word_p: 1
# nlp_random_contextual_word_insertion_bert_uncased_embedding
# initialize model
# ERM
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_projector.weight', 'vocab_projector.bias', 'vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'classifier.bias', 'pre_classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/1564 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-ee9be6c3cf96> in <module>
#      17                             , aug_word_max = 1
#      18                             , aug_word_p = 1
# ---> 19                             , min_char = 4)
#      20
#
# /mnt/hdd/home/helenl/helenl/tta_research/helenl_utils.py in predict_augmented_labels(transform_name, dataset_name, algorithm_name, saved_file_dir, full_dataset, num_samples, aug_char_min, aug_char_max, aug_char_p, aug_word_min, aug_word_max, aug_word_p, aug_sentence_min, aug_sentence_max, aug_sentence_p, min_char)
#     259
#     260             sample = sample.cuda()
# --> 261             raw_pred = alg.model(sample)
#     262             raw_pred = raw_pred.cpu().detach().numpy()
#     263
#
# /mnt/hdd/home/helenl/helenl/tta_research/wilds/examples/models/bert/distilbert.py in __call__(self, x)
#      10         outputs = super().__call__(
#      11             input_ids=input_ids,
# ---> 12             attention_mask=attention_mask,
#      13         )[0]
#      14         return outputs
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     732             output_attentions=output_attentions,
#     733             output_hidden_states=output_hidden_states,
# --> 734             return_dict=return_dict,
#     735         )
#     736         hidden_state = distilbert_output[0]  # (bs, seq_len, dim)
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     555             output_attentions=output_attentions,
#     556             output_hidden_states=output_hidden_states,
# --> 557             return_dict=return_dict,
#     558         )
#     559
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     326
#     327             layer_outputs = layer_module(
# --> 328                 x=hidden_state, attn_mask=attn_mask, head_mask=head_mask[i], output_attentions=output_attentions
#     329             )
#     330             hidden_state = layer_outputs[-1]
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, x, attn_mask, head_mask, output_attentions)
#     286         # Feed Forward Network
#     287         ffn_output = self.ffn(sa_output)  # (bs, seq_length, dim)
# --> 288         ffn_output = self.output_layer_norm(ffn_output + sa_output)  # (bs, seq_length, dim)
#     289
#     290         output = (ffn_output,)
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/modules/normalization.py in forward(self, input)
#     172     def forward(self, input: Tensor) -> Tensor:
#     173         return F.layer_norm(
# --> 174             input, self.normalized_shape, self.weight, self.bias, self.eps)
#     175
#     176     def extra_repr(self) -> str:
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/functional.py in layer_norm(input, normalized_shape, weight, bias, eps)
#    2344             layer_norm, (input,), input, normalized_shape, weight=weight, bias=bias, eps=eps
#    2345         )
# -> 2346     return torch.layer_norm(input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled)
#    2347
#    2348
#
# RuntimeError: CUDA out of memory. Tried to allocate 96.00 MiB (GPU 0; 11.91 GiB total capacity; 9.69 GiB already allocated; 78.94 MiB free; 9.74 GiB reserved in total by PyTorch)

# %%
def calculate_accuracy(prediction_file, sampling_percent = 0.8, num_runs = 10):
    logit_predictions = []
    labels = []
    
    with open(prediction_file, 'rb') as file:
        logit_predictions = np.load(file, allow_pickle = True)
        labels = np.load(file, allow_pickle = True)

    accuracy_scores = []
    
    total_dp = len(logit_predictions) #133782
    
    num_subsamples = int(total_dp * sampling_percent) #107025 for 133782 data points

    for i in tqdm(range(num_runs)):
        random_indices = np.random.choice(np.arange(total_dp), size = num_subsamples, replace = False)

        rand_logit_predictions = np.take(logit_predictions, random_indices, axis = 0)
        matching_labels = np.take(labels, random_indices)
        #print("labels_length", len(matching_labels))
        #print("samples_length", rand_logit_predictions[0])
        
        classified_predictions = []
        for prediction in rand_logit_predictions:
            index_prediction = np.argmax(prediction, axis = 0).tolist()
            classified_predictions.append(index_prediction)
    
        score = sklearn.metrics.accuracy_score(matching_labels, classified_predictions)
        #print(score)
        accuracy_scores.append(score)
    
    return accuracy_scores

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

calculate_accuracy('./ERM_predictions/bert.npy', num_runs = 2)

# %%
def calculate_recall(prediction_file):
    logit_predictions = []
    
    with open(prediction_file, 'rb') as file:
        logit_predictions = np.load(file)
        labels = np.load(file)
        
    #print(true_values)
    classified_predictions = []
    for prediction in logit_predictions:
        index_prediction = np.argmax(prediction, axis = 1).tolist()

        classified_predictions.extend(index_prediction)
            
    score = sklearn.metrics.recall_score(labels, classified_predictions)
    return score

# %%
def show_values(axs, orient="v", space=.01):
    def _single(ax):
        if orient == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height() + (p.get_height()*0.01)
                value = '{:.3f}'.format(p.get_height())
                ax.text(_x, _y, value, ha="center") 
        elif orient == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height() - (p.get_height()*0.5)
                value = '{:.3f}'.format(p.get_width())
                ax.text(_x, _y, value, ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _single(ax)
    else:
        _single(axs)

# %%
"""
Create graph comparing accuracy of all supported augmentations

Parameters:
    augmentations: list of strings, each corresponding to a supported augmentation
    
"""

def create_accuracy_graph(augmentation_file_paths, plot_type = 'bar'):
    
    aug_to_acc = []
    for file_name in augmentation_file_paths:

        accuracies = calculate_accuracy(file_name)
        augmentation = '_'.join(file_name.split('/')[-1].split('.')[0].split('_')[1:])
        print(augmentation)
        for i in range(len(accuracies)):
            accuracy = accuracies[i]
            aug_dict = {"augmentation":augmentation, "accuracy": accuracy, "batch_num": i}
            aug_to_acc.append(aug_dict)

    
    acc_df = pd.DataFrame(aug_to_acc).sort_values('accuracy', ascending = False)
    print(acc_df)
    
    fig, ax = plt.subplots()

    if plot_type == 'bar':
        p = sns.barplot(x = 'augmentation', y = 'accuracy', data = acc_df, ax = ax, ci = 95)
        
    elif plot_type == 'box':
        p = sns.boxplot(x = 'augmentation', y = 'accuracy', data = acc_df, ax = ax)#, order = acc_df['augmentation'])
    

    min_value = acc_df.min()['accuracy']
    max_value = acc_df.max()['accuracy']

    ax.set_ylim(min_value - 0.02, min(1.0, max_value + 0.02))
    

    show_values(p)
    plt.rcParams['figure.figsize'] = (50,10)
    #plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
    plt.show()


"""
Create graph comparing accuracy of all supported augmentations

Parameters:
    augmentations: list of strings, each corresponding to a supported augmentation
    
"""

# %%
def average_standard_augmentation_predictions(standard_file_path, augmentation_file_paths, avg_file_directory):
    with open(standard_file_path, 'rb') as standard_file:
        standard_logit_predictions = np.load(standard_file, allow_pickle = True)
        labels = np.load(standard_file, allow_pickle = True)
        
    for aug_file_path in augmentation_file_paths:
        print(aug_file_path)
        with open(aug_file_path, 'rb') as aug_file:
            aug_logit_predictions = np.load(aug_file, allow_pickle = True)
            
            
        averaged_logit_predictions = (standard_logit_predictions + aug_logit_predictions)/2.0
        
        
        average_file_name = avg_file_directory + aug_file_path.split('/')[-1]
        
        with open(average_file_name, 'wb+') as avg_file:
            np.save(avg_file, averaged_logit_predictions)
            np.save(avg_file, labels)
    

def create_augmentation_impact_graph(averaged_augmentation_file_paths, plot_type = 'bar'):
    aug_to_mean_acc = []
    
    #original_accuracy = statistics.mean(calculate_accuracy('./ERM_predictions/bert.npy'))

    #print("original accuracy:", original_accuracy)
    
    for augmentation_file in averaged_augmentation_file_paths:
        accuracies = calculate_accuracy(augmentation_file)

        augmentation_name = '_'.join(augmentation_file.split('/')[-1].split('.')[0].split('_')[1:]) + "+bert" # remove '.npy' suffix in file name
        
        for accuracy in accuracies:
            aug_dict = {"augmentation":augmentation_name, "accuracy": accuracy}
            aug_to_mean_acc.append(aug_dict)
    
    acc_df = pd.DataFrame(aug_to_mean_acc).sort_values('accuracy', ascending = False)
    print(acc_df)
    
    fig, ax = plt.subplots()

    if plot_type == 'bar':
        p = sns.barplot(x = 'augmentation', y = 'accuracy', data = acc_df, ax = ax, ci = 95)
        
    elif plot_type == 'box':
        p = sns.boxplot(x = 'augmentation', y = 'accuracy', data = acc_df, ax = ax)#, order = acc_df['augmentation'])
    
    sns.set(rc = {'figure.figsize':(50,20)})
    
    min_value = acc_df.min()['accuracy']
    max_value = acc_df.max()['accuracy']

    ax.set_ylim(min_value - 0.02, min(1.0, max_value + 0.02))
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

    
    show_values(p)

    

    #ax.figure.set_size_inches(200,10)

# %%
aug_files = []

aug_file_dir = './ERM_predictions_optimized_params/'
for file in os.listdir(aug_file_dir):
    full_path = aug_file_dir + file
    
    if os.path.isfile(full_path) and full_path.split('.')[-1] == 'npy':
        aug_files.append(full_path)

aug_files.append('./ERM_predictions/bert.npy')

        
average_standard_augmentation_predictions('./ERM_predictions/bert.npy'
                                          , aug_files
                                          , './ERM_predictions_optimized_params/averaged_with_bert/')

# %%
aug_files = []

raw_aug_file_dir = './data/civilcomments_ERM_predictions_optimized_params/raw/'
with_bert_aug_file_dir = './data/civilcomments_ERM_predictions_optimized_params/with_bert/'

for file in os.listdir(raw_aug_file_dir):    
        full_path = raw_aug_file_dir + file
        
        if os.path.isfile(full_path) and full_path.split('.')[-1] == 'npy':
            aug_files.append(full_path)

#aug_files.append('./ERM_predictions/bert.npy')

   

average_standard_augmentation_predictions('./data/civilcomments_ERM_predictions/bert.npy'
                                          , aug_files
                                          , './data/civilcomments_ERM_predictions_optimized_params/with_bert/')
# Out:
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_contextual_word_insertion_squeezebert_uncased_embedding.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_word_delete.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_antonym.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_contextual_word_insertion_distilbert_cased_embedding.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_wordnet_synonym.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_char_insert.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_contextual_word_substitution_bert_uncased_embedding.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_token_split.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_contextual_word_substitution_distilroberta_base_embedding.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_contextual_word_substitution_roberta_embedding.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_contextual_word_substitution_bart_base_embedding.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_contextual_word_substitution_distilbert_cased_embedding.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_char_substitution.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_contextual_word_insertion_bert_cased_embedding.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_contextual_word_substitution_distilbert_uncased_embedding.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_word_swap.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_contextual_word_substitution_bert_cased_embedding.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_contextual_word_insertion_distilbert_uncased_embedding.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_spelling_substitution.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_ocr.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_contextual_word_substitution_squeezebert_uncased_embedding.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_keyboard.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_char_swap.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_word_substitute.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_contextual_word_insertion_roberta_base_embedding.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_char_deletion.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_contextual_word_insertion_bart_base_embedding.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_contextual_word_insertion_bert_uncased_embedding.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_ppdb_synonym.npy
# ./data/civilcomments_ERM_predictions_optimized_params/raw/nlp_random_contextual_word_insertion_distilroberta_base_embedding.npy

# %%
aug_files = []

aug_file_dir = './data/civilcomments_ERM_predictions_optimized_params/with_bert/'
for file in os.listdir(aug_file_dir):
    full_path = aug_file_dir + file
    
    if os.path.isfile(full_path) and full_path.split('.')[-1] == 'npy':
        aug_files.append(full_path)

aug_files.append('./data/civilcomments_ERM_predictions/bert.npy')

# %%
create_augmentation_impact_graph(aug_files, plot_type = 'bar')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#                   augmentation  accuracy
# 293          ppdb_synonym+bert  0.927307
# 297          ppdb_synonym+bert  0.927288
# 13                       +bert  0.927054
# 323                      +bert  0.927054
# 17                       +bert  0.926989
# ..                         ...       ...
# 69     random_char_insert+bert  0.924765
# 264  random_char_deletion+bert  0.924737
# 66     random_char_insert+bert  0.924672
# 268  random_char_deletion+bert  0.924616
# 269  random_char_deletion+bert  0.924588
#
# [330 rows x 2 columns]

# %%
supported_augment_labels = ['bert'
                           , 'nlp_ocr'
                           , 'nlp_keyboard'
                           , 'nlp_random_char_insert'
                           , 'nlp_random_char_substitution'
                           , 'nlp_random_char_swap'
                           , 'nlp_random_char_deletion'
                           , 'nlp_spelling_substitution'
                           , 'nlp_random_word_swap'
                           , 'nlp_random_word_delete'
                           #, 'nlp_random_crop'
                           #, 'nlp_random_token_split'
                           #, 'nlp_back_translation_aug'
                           ]

# %%
file_dir_name = 'ERM_predictions_optimized_params'
aug_paths = []

for filename in os.listdir(file_dir_name):
    full_path = './' + file_dir_name + '/' + filename
    
    if full_path.split('.')[-1] == 'npy':
        aug_paths.append(full_path)
    

aug_paths.append('./ERM_predictions/bert.npy')
create_accuracy_graph(aug_paths)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# random_word_delete
#   0%|          | 0/10 [00:00<?, ?it/s]
# antonym
#   0%|          | 0/10 [00:00<?, ?it/s]
# wordnet_synonym
#   0%|          | 0/10 [00:00<?, ?it/s]
# random_char_insert
#   0%|          | 0/10 [00:00<?, ?it/s]
# random_token_split
#   0%|          | 0/10 [00:00<?, ?it/s]
# random_char_substitution
#   0%|          | 0/10 [00:00<?, ?it/s]
# random_word_swap
#   0%|          | 0/10 [00:00<?, ?it/s]
# ocr
#   0%|          | 0/10 [00:00<?, ?it/s]
# keyboard
#   0%|          | 0/10 [00:00<?, ?it/s]
# random_char_swap
#   0%|          | 0/10 [00:00<?, ?it/s]
# random_char_deletion
#   0%|          | 0/10 [00:00<?, ?it/s]
# random_contextual_word_insertion_bert_uncased_embedding
#   0%|          | 0/10 [00:00<?, ?it/s]
# ppdb_synonym
#   0%|          | 0/10 [00:00<?, ?it/s]
# random_substitute
#   0%|          | 0/10 [00:00<?, ?it/s]
#            augmentation  accuracy  batch_num
# 149                      0.926933          9
# 142                      0.926905          2
# 122        ppdb_synonym  0.926858          2
# 146                      0.926653          6
# 128        ppdb_synonym  0.926634          8
# ..                  ...       ...        ...
# 35   random_char_insert  0.919757          5
# 82             keyboard  0.919720          2
# 39   random_char_insert  0.919664          9
# 32   random_char_insert  0.919645          2
# 36   random_char_insert  0.919234          6
#
# [150 rows x 3 columns]

# %%
create_accuracy_graph(supported_augment_labels)
#create_accuracy_graph(['bert'])
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#                     augmentation  accuracy  batch_num
# 7                           bert  0.926942          7
# 4                           bert  0.926896          4
# 5                           bert  0.926671          5
# 0                           bert  0.926634          0
# 8                           bert  0.926550          8
# ..                           ...       ...        ...
# 29                  nlp_keyboard  0.909591          9
# 26                  nlp_keyboard  0.909544          6
# 45  nlp_random_char_substitution  0.909451          5
# 28                  nlp_keyboard  0.909432          8
# 25                  nlp_keyboard  0.909180          5
#
# [100 rows x 3 columns]

# %%
create_augmentation_impact_graph(supported_augment_labels)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# original accuracy: 0.9264573697734174
#   0%|          | 0/10 [00:00<?, ?it/s]
# AUG AVERAGE: 0.926615276804485
# MEAN WITH BERT: 0.9265363232889512
#   0%|          | 0/10 [00:00<?, ?it/s]
# AUG AVERAGE: 0.9194431207661762
# MEAN WITH BERT: 0.9229502452697969
#   0%|          | 0/10 [00:00<?, ?it/s]
# AUG AVERAGE: 0.9100238262088297
# MEAN WITH BERT: 0.9182405979911236
#   0%|          | 0/10 [00:00<?, ?it/s]
# AUG AVERAGE: 0.9105414622751693
# MEAN WITH BERT: 0.9184994160242934
#   0%|          | 0/10 [00:00<?, ?it/s]
# AUG AVERAGE: 0.9106106049988321
# MEAN WITH BERT: 0.9185339873861247
#   0%|          | 0/10 [00:00<?, ?it/s]
# AUG AVERAGE: 0.9106694697500584
# MEAN WITH BERT: 0.9185634197617378
#   0%|          | 0/10 [00:00<?, ?it/s]
# AUG AVERAGE: 0.911381452931558
# MEAN WITH BERT: 0.9189194113524877
#   0%|          | 0/10 [00:00<?, ?it/s]
# AUG AVERAGE: 0.9216622284512964
# MEAN WITH BERT: 0.9240597991123569
#   0%|          | 0/10 [00:00<?, ?it/s]
# AUG AVERAGE: 0.9257164213968699
# MEAN WITH BERT: 0.9260868955851437
#   0%|          | 0/10 [00:00<?, ?it/s]
# AUG AVERAGE: 0.9183097407147862
# MEAN WITH BERT: 0.9223835552441018
# [{'augmentation': '+bert', 'accuracy': 0.9265363232889512}, {'augmentation': 'ocr+bert', 'accuracy': 0.9229502452697969}, {'augmentation': 'keyboard+bert', 'accuracy': 0.9182405979911236}, {'augmentation': 'random_char_insert+bert', 'accuracy': 0.9184994160242934}, {'augmentation': 'random_char_substitution+bert', 'accuracy': 0.9185339873861247}, {'augmentation': 'random_char_swap+bert', 'accuracy': 0.9185634197617378}, {'augmentation': 'random_char_deletion+bert', 'accuracy': 0.9189194113524877}, {'augmentation': 'spelling_substitution+bert', 'accuracy': 0.9240597991123569}, {'augmentation': 'random_word_swap+bert', 'accuracy': 0.9260868955851437}, {'augmentation': 'random_word_delete+bert', 'accuracy': 0.9223835552441018}]
#                     augmentation  accuracy
# 0                          +bert  0.926536
# 8          random_word_swap+bert  0.926087
# 7     spelling_substitution+bert  0.924060
# 1                       ocr+bert  0.922950
# 9        random_word_delete+bert  0.922384
# 6      random_char_deletion+bert  0.918919
# 5          random_char_swap+bert  0.918563
# 4  random_char_substitution+bert  0.918534
# 3        random_char_insert+bert  0.918499
# 2                  keyboard+bert  0.918241

# %% [markdown]
# # Experiment: Averaging Across Number of Samples Per Augmentation

# %%
for samples in range(2, 11):
    predict_augmented_labels('nlp_random_word_delete'
                            , num_samples = samples
                            , aug_word_min = 1
                            , aug_word_max = 1
                            , aug_word_p = 1)
# Out:
# num_samples: 2
# num_samples: 2
# num_samples: 2
# num_samples: 2
# num_samples: 2
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# tensor([[[[  101,     1],
#           [ 2821,     1],
#           [ 2748,     1],
#           ...,
#           [    0,     0],
#           [    0,     0],
#           [    0,     0]],
#
#          [[  101,     1],
#           [ 2821,     1],
#           [ 2748,     1],
#           ...,
#           [    0,     0],
#           [    0,     0],
#           [    0,     0]]],
#
#
#         [[[  101,     1],
#           [ 2002,     1],
#           [ 1005,     1],
#           ...,
#           [    0,     0],
#           [    0,     0],
#           [    0,     0]],
#
#          [[  101,     1],
#           [ 2002,     1],
#           [ 1005,     1],
#           ...,
#           [    0,     0],
#           [    0,     0],
#           [    0,     0]]],
#
#
#         [[[  101,     1],
#           [ 3393,     1],
#           [ 2721,     1],
#           ...,
#           [    0,     0],
#           [    0,     0],
#           [    0,     0]],
#
#          [[  101,     1],
#           [ 3393,     1],
#           [ 2721,     1],
#           ...,
#           [    0,     0],
#           [    0,     0],
#           [    0,     0]]],
#
#
#         ...,
#
#
#         [[[  101,     1],
#           [ 2339,     1],
#           [ 1996,     1],
#           ...,
#           [    0,     0],
#           [    0,     0],
#           [    0,     0]],
#
#          [[  101,     1],
#           [ 2339,     1],
#           [16939,     1],
#           ...,
#           [    0,     0],
#           [    0,     0],
#           [    0,     0]]],
#
#
#         [[[  101,     1],
#           [ 2720,     1],
#           [ 1012,     1],
#           ...,
#           [    0,     0],
#           [    0,     0],
#           [    0,     0]],
#
#          [[  101,     1],
#           [ 2720,     1],
#           [ 1012,     1],
#           ...,
#           [    0,     0],
#           [    0,     0],
#           [    0,     0]]],
#
#
#         [[[  101,     1],
#           [ 5262,     1],
#           [ 1010,     1],
#           ...,
#           [    0,     0],
#           [    0,     0],
#           [    0,     0]],
#
#          [[  101,     1],
#           [ 5262,     1],
#           [ 1010,     1],
#           ...,
#           [    0,     0],
#           [    0,     0],
#           [    0,     0]]]])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-3b9e2d4b5d4d> in <module>
#       4                             , aug_word_min = 1
#       5                             , aug_word_max = 1
# ----> 6                             , aug_word_p = 1)
#
# <ipython-input-40-8e89123ce0be> in predict_augmented_labels(transform_name, num_samples, aug_char_min, aug_char_max, aug_char_p, aug_word_min, aug_word_max, aug_word_p, min_char)
#     133         #pdb.set_trace()
#     134         print(batch[0])
# --> 135         raw_pred = alg.model(batch[0].cuda()).cpu().detach().numpy()
#     136
#     137         #softmax_prediction = sp.special.softmax(raw_pred.cpu().detach().numpy()).tolist()
#
# /mnt/hdd/home/helenl/helenl/tta_research/wilds/examples/models/bert/distilbert.py in __call__(self, x)
#      10         outputs = super().__call__(
#      11             input_ids=input_ids,
# ---> 12             attention_mask=attention_mask,
#      13         )[0]
#      14         return outputs
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     732             output_attentions=output_attentions,
#     733             output_hidden_states=output_hidden_states,
# --> 734             return_dict=return_dict,
#     735         )
#     736         hidden_state = distilbert_output[0]  # (bs, seq_len, dim)
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     555             output_attentions=output_attentions,
#     556             output_hidden_states=output_hidden_states,
# --> 557             return_dict=return_dict,
#     558         )
#     559
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     326
#     327             layer_outputs = layer_module(
# --> 328                 x=hidden_state, attn_mask=attn_mask, head_mask=head_mask[i], output_attentions=output_attentions
#     329             )
#     330             hidden_state = layer_outputs[-1]
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, x, attn_mask, head_mask, output_attentions)
#     275             mask=attn_mask,
#     276             head_mask=head_mask,
# --> 277             output_attentions=output_attentions,
#     278         )
#     279         if output_attentions:
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /local/helenl/.conda/envs/tta/lib/python3.6/site-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, query, key, value, mask, head_mask, output_attentions)
#     181             seq_length, dim) Contextualized layer. Optional: only if `output_attentions=True`
#     182         """
# --> 183         bs, q_length, dim = query.size()
#     184         k_length = key.size(1)
#     185         # assert dim == self.dim, f'Dimensions do not match: {dim} input vs {self.dim} configured'
#
# ValueError: too many values to unpack (expected 3)

# %%
# PLOT: corruptions vs. corrections
# subsample 80% to create error bars -> add more rows for each run to generate error bars
        
# TFIDF 33 hours RT: check gpustat; is implementation necessary for our experiments?

# Report group-specific accuracy (identities; detecting hate-speech towards specific groups)
    # Similar corruptions vs. corrections
    # See WILDS documentation for metadata
    # Make one for each augmentation (x axis identity group, y axis performance)

    
# Modify parameter of how many modifications there are (1 word, 2 words)
    # x is intensity of augmentation, y is accuracy
    # For a specific augmentation, how does average response change (higher intensity + original)

# x-axis: number of draws, y-axis: average performance across draws
    # Up to 20 or 50 draws of words to delete/characters to augment
    # up to 50 for words, 100 for char

# %% [markdown]
# # Corrections and Corruptions

# %%
# CORRUPTIONS VS. CORRECTIONS GRAPH

"""
Function that calculates raw number of corrections and corruptions generated by an augmentation.

Parameters:
    
    aug_pred_file: String containing path to .npy file with logit predictions and labels from augmentation model.
    original_pred_file: String containing path to .npy file with logit predictions and labels from original model.
    
Returns:

    corrections_corruptions_dict: Dictionary with two entries: "corruptions" key mapped to number (int) of raw corruptions created by augmentation,
                                    and "corrections" key mapped to number (int) of raw corrections created by augmentation.
    

"""
def calculate_corrections_corruptions(aug_pred_file, original_pred_file):
    aug_logit_predictions = []
    aug_classified_predictions = []
    
    original_logit_predictions = []
    original_classified_predictions = []
    
    aug_labels = []
    original_labels = []
    
    with open(aug_pred_file, 'rb') as aug_file:
        aug_logit_predictions = np.load(aug_file, allow_pickle = True)
        aug_labels = np.load(aug_file, allow_pickle = True)
    
    with open(original_pred_file, 'rb') as original_file:
        original_logit_predictions = np.load(original_file, allow_pickle = True)
        original_labels = np.load(original_file, allow_pickle = True)
        
    assert aug_labels.all() == original_labels.all(), "Test set labels do not match between aug. and original."
    assert aug_labels.size == 133782
    assert original_labels.size == 133782
    
    for prediction in aug_logit_predictions:
        index_prediction = np.argmax(prediction).tolist()
        
        aug_classified_predictions.append(index_prediction)
    
    for prediction in original_logit_predictions:
        index_prediction = np.argmax(prediction).tolist()
        
        original_classified_predictions.append(index_prediction)
    
    
    corrections_count = 0
    corrections_indices = []
    
    corruptions_count = 0
    corruptions_indices = []
    
    for i in range(len(aug_labels)):
        label = original_labels[i]
        original_pred = original_classified_predictions[i]
        aug_pred = aug_classified_predictions[i]
        
        
        # if corruption
        if (original_pred == label and aug_pred != label):
            corruptions_count += 1
            corruptions_indices.append(i)
        
        # if correction
        elif (original_pred != label and aug_pred == label):
            corrections_count += 1
            corrections_indices.append(i)
    
    corrections_corruptions_dict = {"num_corrections": corrections_count
                                    , "num_corruptions": corruptions_count
                                   , "corrections_indices": corrections_indices
                                   , "corruptions_indices": corruptions_indices}
    
    return corrections_corruptions_dict

# %%
def create_corrections_corruptions_plots(accuracy_file_paths):
    aug_to_corrections_corruptions = []
    
    for file_name in accuracy_file_paths:
        original_file_name = './ERM_predictions/bert.npy'
        
        corrections_corruptions_dict = calculate_corrections_corruptions(file_name, original_file_name)
        
        corrections = corrections_corruptions_dict["num_corrections"]
        corruptions = corrections_corruptions_dict["num_corruptions"]
        
        print(file_name)
        
        # augmentation = int(file_name.split('/')[-1].split('.')[0].split('_')[-1]) # augmentation name for word experiment plot
        
        augmentation = float(file_name.split('/')[1].split('_')[-1]) # augmentation name for char experiment plot
        aug_dict = {"augmentation":augmentation, "corrections": corrections, "corruptions": corruptions}
        aug_to_corrections_corruptions.append(aug_dict)

    
    acc_df = pd.DataFrame(aug_to_corrections_corruptions)
    #print(acc_df)
    

    acc_df_melted = acc_df.reset_index().melt(id_vars = 'augmentation')
    acc_df_melted = acc_df_melted[acc_df_melted.variable != 'index']

    print(acc_df_melted)
    

    sns.set(rc = {'figure.figsize':(30,10)})
    p = sns.barplot(x = 'augmentation', y = 'value', hue = 'variable', data = acc_df_melted, ci = False, palette = ["green", "red"])#, order = acc_df['augmentation'])

    #p = sns.boxplot(x = 'augmentation', y = 'value', hue = 'variable', data = acc_df_melted, palette = ["green", "red"])#, order = acc_df['augmentation'])
    show_values(p)

# %% [markdown]
# ## Across different augmentation types

# %%
supported_augment_labels = ['nlp_ocr'
                           , 'nlp_keyboard'
                           , 'nlp_random_char_insert'
                           , 'nlp_random_char_substitution'
                           , 'nlp_random_char_swap'
                           , 'nlp_random_char_deletion'
                           , 'nlp_spelling_substitution'
                           , 'nlp_random_word_swap'
                           , 'nlp_random_word_delete']

file_paths = []

for augmentation in supported_augment_labels:
    file_name = './ERM_predictions/' + augmentation + ".npy"
    file_paths.append(file_Name)



create_corrections_corruptions_plots(file_paths)
# Out:
#                     augmentation     variable  value
# 9                        nlp_ocr  corrections   1938
# 10                  nlp_keyboard  corrections   2440
# 11        nlp_random_char_insert  corrections   2576
# 12  nlp_random_char_substitution  corrections   2512
# 13          nlp_random_char_swap  corrections   2389
# 14      nlp_random_char_deletion  corrections   2228
# 15     nlp_spelling_substitution  corrections   1701
# 16          nlp_random_word_swap  corrections   1062
# 17        nlp_random_word_delete  corrections   1796
# 18                       nlp_ocr  corruptions   2901
# 19                  nlp_keyboard  corruptions   4673
# 20        nlp_random_char_insert  corruptions   4730
# 21  nlp_random_char_substitution  corruptions   4664
# 22          nlp_random_char_swap  corruptions   4508
# 23      nlp_random_char_deletion  corruptions   4280
# 24     nlp_spelling_substitution  corruptions   2557
# 25          nlp_random_word_swap  corruptions   1140
# 26        nlp_random_word_delete  corruptions   3080

# %% [markdown]
# ## For word experiment:

# %%
word_experiments_dir = 'ERM_word_frequency_experiment'

experiment_file_paths = []

for filename in os.listdir(word_experiments_dir):
    full_path = './' + word_experiments_dir + '/' + filename

    if os.path.isfile(full_path):
        experiment_file_paths.append(full_path)
        
create_corrections_corruptions_plots(experiment_file_paths)

# %% [markdown]
# ## For char experiment:

# %%
char_experiments_dir = 'ERM_char_frequency_experiment_2'

experiment_file_paths = []

for subdir in os.listdir(char_experiments_dir):
    subdir_path = char_experiments_dir + "/" + subdir
    
    if os.path.isdir(subdir_path):
        
        for file in os.listdir(subdir_path):
            file_path = subdir_path + "/" + file
            
            #print(file_path)
            if file_path[-5:] == '1.npy':
                experiment_file_paths.append(file_path)
        
print(experiment_file_paths)
create_corrections_corruptions_plots(experiment_file_paths)
# Out:
# ['ERM_char_frequency_experiment_2/word_p_0.20/word_p_0.2nlp_random_word_delete_aug_size_1.npy', 'ERM_char_frequency_experiment_2/word_p_0.05/word_p_0.05nlp_random_word_delete_aug_size_1.npy', 'ERM_char_frequency_experiment_2/word_p_0.25/word_p_0.25nlp_random_word_delete_aug_size_1.npy', 'ERM_char_frequency_experiment_2/word_p_0.10/word_p_0.1nlp_random_word_delete_aug_size_1.npy', 'ERM_char_frequency_experiment_2/word_p_0.50/word_p_0.5nlp_random_word_delete_aug_size_1.npy', 'ERM_char_frequency_experiment_2/word_p_0.75/word_p_0.75nlp_random_word_delete_aug_size_1.npy']
# ERM_char_frequency_experiment_2/word_p_0.20/word_p_0.2nlp_random_word_delete_aug_size_1.npy
# ERM_char_frequency_experiment_2/word_p_0.05/word_p_0.05nlp_random_word_delete_aug_size_1.npy
# ERM_char_frequency_experiment_2/word_p_0.25/word_p_0.25nlp_random_word_delete_aug_size_1.npy
# ERM_char_frequency_experiment_2/word_p_0.10/word_p_0.1nlp_random_word_delete_aug_size_1.npy
# ERM_char_frequency_experiment_2/word_p_0.50/word_p_0.5nlp_random_word_delete_aug_size_1.npy
# ERM_char_frequency_experiment_2/word_p_0.75/word_p_0.75nlp_random_word_delete_aug_size_1.npy
#     augmentation     variable  value
# 6           0.20  corrections   1865
# 7           0.05  corrections    771
# 8           0.25  corrections   2159
# 9           0.10  corrections   1199
# 10          0.50  corrections   3026
# 11          0.75  corrections   3589
# 12          0.20  corruptions   2998
# 13          0.05  corruptions   1147
# 14          0.25  corruptions   3745
# 15          0.10  corruptions   1739
# 16          0.50  corruptions   6610
# 17          0.75  corruptions   8720

# %% [markdown]
# ## Code for analyzing corrections/corruptions comments

# %%
def extract_corrections_corruptions_inputs(augmentation_file_path, standard_file_path, correction_corruption_type):
    """
    Retrieves comments, labels, and metadata for either corrections or corruptions made by a provided augmentation.

    Parameters:
        augmentation_file_path:      String denoting full path to augmentation prediction file.
        standard_file_path:          String denoting full path to non-augmented prediction file.
        correction_corruption_type:  Either "correction" or "corruption" to indicate if correction or corruption data is to be returned.

    Returns:
        A tuple of length 3, with :
            - the first index containing a list of the comments (type string) of interest.
            - the second index containing a list of labels (type int) for each of the comments in the first index.
                - the third index containing a list of tensors containing the metadata for each of the comments in the first index.
"""
    
    eval_inputs = get_eval_dataset()
    print(eval_inputs)
    corrections_corruptions_dict = calculate_corrections_corruptions(augmentation_file_path, standard_file_path)
    
    if correction_corruption_type == 'correction':
        indices = corrections_corruptions_dict['corrections_indices']
        
    elif correction_corruption_type == 'corruption':
        indices = corrections_corruptions_dict['corruptions_indices']
    
    inputs = []
    labels = []
    metadata = []
    
    for i in indices:
        inputs.append(eval_inputs[i][0])
        labels.append(eval_inputs[i][1].item())
        metadata.append(eval_inputs[i][2])
        
    return (inputs, labels, metadata)

# %%
def create_word_cloud(comments_list, stopwords = set()):
    """
    Creates a wordcloud.
    
    Parameters:
        comments_list: List of strings to be used as inputs into the wordcloud.
        stopwords:     Set of words to be excluded from wordcloud. 
                       Default value is an empty set (so that all input words will be included in forming wordcloud.)
                       If None is passed in, WordCloud library's STOPWORDS list will be used as words to be excluded.
    
    Returns:
        None.
    """
    words = ""
    
    for comment in comments_list:
 
        # split the value
        tokens = comment.split()
     
        # Converts each token into lowercase
        for i in range(len(tokens)):
            tokens[i] = tokens[i].lower()
     
    words += " ".join(tokens)+" "
 
    wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(words)
    
    # plot the WordCloud image                      
    plt.figure(figsize = (8, 8), facecolor = None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad = 0)

    plt.show()

# %% [markdown]
# ## 10-word deletion correction/corruption content analysis:

# %%
del_10_corrections_inputs = extract_corrections_corruptions_inputs('./ERM_word_frequency_experiment/nlp_random_word_delete_aug_size_10.npy'
                                                                   , './ERM_predictions/bert.npy'
                                                                   , 'correction')

del_10_corrections_labels = del_10_corrections_inputs[1]

tox_corrected = sum(del_10_corrections_labels)
nontox_corrected = len(del_10_corrections_labels) - tox_corrected

print("toxic corrected:", tox_corrected) # toxic comments mislabeled by BERT as nontoxic but corrected with augmentation
print("nontoxic corrected:", nontox_corrected) # nontoxic comments mislabeled by BERT as toxic but corrected with augmentation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-aac68b8457a0> in <module>
# ----> 1 del_10_corrections_inputs = extract_corrections_corruptions_inputs('./ERM_word_frequency_experiment/nlp_random_word_delete_aug_size_10.npy'
#       2                                                                    , './ERM_predictions/bert.npy'
#       3                                                                    , 'correction')
#       4
#       5 del_10_corrections_labels = del_10_corrections_inputs[1]
#
# NameError: name 'extract_corrections_corruptions_inputs' is not defined

# %%
del_10_corruptions_inputs = extract_corrections_corruptions_inputs('./ERM_word_frequency_experiment/nlp_random_word_delete_aug_size_10.npy'
                                                                   , './ERM_predictions/bert.npy'
                                                                   , 'corruption')

del_10_corruptions_labels = del_10_corruptions_inputs[1]

tox_corrupted = sum(del_10_corruptions_labels)
nontox_corrupted = len(del_10_corruptions_labels) - tox_corrupted

print("toxic corrupted:", tox_corrupted) # toxic comments correctly labeled by BERT as toxic but corrupted with augmentation
print("nontoxic corrupted:", nontox_corrupted) # nontoxic comments correctly labeled by BERT as nontoxic but corrupted with augmentation
# Out:
# bert: 1
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# toxic corrupted: 3075
# nontoxic corrupted: 856

# %%
create_word_cloud(del_10_corrections_inputs[0])

# %%
create_word_cloud(del_10_corrections_inputs[0], None)

# %%
# word cloud of inputs that were mislabeled as nontoxic by BERT but corrected by augmentation
create_word_cloud([del_10_corrections_inputs[0][i] 
                   for i in range(len(del_10_corrections_inputs[1])) 
                   if del_10_corrections_inputs[1][i] == 1])

# %%
# word cloud of inputs that were mislabeled as nontoxic by BERT but corrected by augmentation
create_word_cloud([del_10_corrections_inputs[0][i] 
                   for i in range(len(del_10_corrections_inputs[1])) 
                   if del_10_corrections_inputs[1][i] == 1]
                 , None)

# %%
# word cloud of inputs that were mislabeled as nontoxic by BERT but corrected by augmentation
create_word_cloud([del_10_corrections_inputs[0][i] 
                   for i in range(len(del_10_corrections_inputs[1])) 
                   if del_10_corrections_inputs[1][i] == 0])

# %%
# word cloud of inputs that were mislabeled as nontoxic by BERT but corrected by augmentation
create_word_cloud([del_10_corrections_inputs[0][i] 
                   for i in range(len(del_10_corrections_inputs[1])) 
                   if del_10_corrections_inputs[1][i] == 0]
                 , None)

# %%
create_word_cloud(del_10_corruptions_inputs[0])

# %%
create_word_cloud(del_10_corruptions_inputs[0], None)

# %%
# word cloud of inputs that were correctly labeled as toxic by BERT but corrupted by augmentation
create_word_cloud([del_10_corruptions_inputs[0][i] 
                   for i in range(len(del_10_corruptions_inputs[1])) 
                   if del_10_corruptions_inputs[1][i] == 1])

# %%
# word cloud of inputs that were correctly labeled as toxic by BERT but corrupted by augmentation
create_word_cloud([del_10_corruptions_inputs[0][i] 
                   for i in range(len(del_10_corruptions_inputs[1])) 
                   if del_10_corruptions_inputs[1][i] == 1]
                 , None)

# %%
# word cloud of inputs that were correctly labeled as nontoxic by BERT but corrupted by augmentation
create_word_cloud([del_10_corruptions_inputs[0][i] 
                   for i in range(len(del_10_corruptions_inputs[1])) 
                   if del_10_corruptions_inputs[1][i] == 0]
                 )

# %%
# word cloud of inputs that were correctly labeled as nontoxic by BERT but corrupted by augmentation
create_word_cloud([del_10_corruptions_inputs[0][i] 
                   for i in range(len(del_10_corruptions_inputs[1])) 
                   if del_10_corruptions_inputs[1][i] == 0]
                  , None)

# %% [markdown]
# ### TF-IDF analysis of commen words

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

corrections_corpus = del_10_corrections_inputs[0]

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corrections_corpus)

X.toarray()
# Out:
# 1.0

# %% [markdown]
# ### Heat-map of input overlap across different augmentations

# %%
def calculate_comment_overlap(indices_1, indices_2):
    num_overlap = 0.0

    
    set_1 = set(indices_1)
    set_2 = set(indices_2)
    
    unique_indices = set.union(set_1, set_2)
    max_index = max(max(set_1), max(set_2))

    for i in range(0, max_index + 1):
        if (i in set_1) and (i in set_2):
            num_overlap += 1
    
    num_unique_indices = len(unique_indices)

    return num_overlap/num_unique_indices 

def create_heatmap(aug_to_indices_dict, corrections = True):
    labels = sorted(list(aug_to_indices_dict.keys()))
    
    data = []
    
    for i in labels:
        row = []
        i_indices = aug_to_indices_dict[i]
        
        for j in labels:
            j_indices = aug_to_indices_dict[j]
            
            similarity = calculate_comment_overlap(i_indices, j_indices)
            row.append(similarity)
            
        data.append(row)
       
    print(data)
    fig, ax = plt.subplots()
    im = ax.imshow(data, cmap = 'viridis')
    
    str_labels = [str(label) for label in labels]
    
    ax.set_xticks(np.arange(0, len(labels), 1))
    ax.set_yticks(np.arange(0, len(labels), 1))
    
    ax.set_xticklabels(str_labels)
    ax.set_yticklabels(str_labels)
    
    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    
    for i in range(len(labels)):
        for j in range(len(labels)):
            text = ax.text(j, i, round(data[i][j], 1),
                           ha="center", va="center", color="w")
       
    for k, v in ax.spines.items():
        v.set_visible(False)
    
    
    ax.set_xticks(np.arange(len(data[0])+1)-.5, minor=True)
    ax.set_yticks(np.arange(len(data)+1)-.5, minor=True)
    
    #ax.grid(which="major", color="w", linestyle='-', linewidth=3)

    ax.tick_params(which="minor", bottom=False, left=False)
    
    if corrections:
        ax.set_title("Corrections comment overlap")
    else:
        ax.set_title("Corruptions comment overlap")

    fig.tight_layout()
    plt.show()

# %%
aug_to_correction_indices = {}
aug_to_corruption_indices = {}

char_experiments_dir_1 = 'ERM_char_frequency_experiment_2/word_p_0.10'


for filename in os.listdir(char_experiments_dir_1):
    full_path = './' + char_experiments_dir_1 + '/' + filename

    if os.path.isfile(full_path) and full_path[-4:] == '.npy':
        print(full_path)
        corrections_corruptions_dict = calculate_corrections_corruptions(full_path, './ERM_predictions/bert.npy')
        
        num_corrections = corrections_corruptions_dict['num_corrections']
        num_corruptions = corrections_corruptions_dict['num_corruptions']
        
        corrections_indices = corrections_corruptions_dict['corrections_indices']
        corruptions_indices = corrections_corruptions_dict['corruptions_indices']
        
        assert num_corrections == len(corrections_indices), "number of corrections does not match indices provided"
        assert num_corruptions == len(corruptions_indices), "number of corruptions does not match indices provided"
        
        aug = int(full_path.split('/')[-1].split('.')[1].split('_')[-1])
        aug_to_correction_indices[aug] = set(corrections_indices)
        aug_to_corruption_indices[aug] = set(corruptions_indices)
# Out:
# ./ERM_char_frequency_experiment_2/word_p_0.10/word_p_0.1nlp_random_word_delete_aug_size_2.npy
# ./ERM_char_frequency_experiment_2/word_p_0.10/word_p_0.1nlp_random_word_delete_aug_size_1.npy
# ./ERM_char_frequency_experiment_2/word_p_0.10/word_p_0.1nlp_random_word_delete_aug_size_3.npy
# ./ERM_char_frequency_experiment_2/word_p_0.10/word_p_0.1nlp_random_word_delete_aug_size_4.npy

# %%
create_heatmap(aug_to_correction_indices)
print(aug_to_correction_indices.keys())
# Out:
# [[1.0, 0.20432813286361348, 0.2066365007541478, 0.21780684104627768], [0.20432813286361348, 1.0, 0.19391824526420737, 0.1913214990138067], [0.2066365007541478, 0.19391824526420737, 1.0, 0.20607267297162768], [0.21780684104627768, 0.1913214990138067, 0.20607267297162768, 1.0]]
# dict_keys([2, 1, 3, 4])

# %%
create_heatmap(aug_to_corruption_indices, corrections = False)
# Out:
# [[1.0, 0.16873949579831932, 0.16005291005291006, 0.16737635113003602], [0.16873949579831932, 1.0, 0.15323906609667873, 0.16475972540045766], [0.16005291005291006, 0.15323906609667873, 1.0, 0.16348332793784395], [0.16737635113003602, 0.16475972540045766, 0.16348332793784395, 1.0]]

# %%
aug_to_correction_indices = {}
aug_to_corruption_indices = {}

char_experiments_dir = 'ERM_char_frequency_experiment_2'

experiment_file_paths = []

for subdir in os.listdir(char_experiments_dir):
    subdir_path = char_experiments_dir + "/" + subdir
    
    if os.path.isdir(subdir_path):
        
        for file in os.listdir(subdir_path):
            full_path = subdir_path + "/" + file
            
            if full_path[-5:] == '1.npy':
                
                corrections_corruptions_dict = calculate_corrections_corruptions(full_path, './ERM_predictions/bert.npy')
        
                num_corrections = corrections_corruptions_dict['num_corrections']
                num_corruptions = corrections_corruptions_dict['num_corruptions']

                corrections_indices = corrections_corruptions_dict['corrections_indices']
                corruptions_indices = corrections_corruptions_dict['corruptions_indices']

                assert num_corrections == len(corrections_indices), "number of corrections does not match indices provided"
                assert num_corruptions == len(corruptions_indices), "number of corruptions does not match indices provided"

                print(full_path)
                aug = float(full_path.split('/')[1].split('_')[-1])
                aug_to_correction_indices[aug] = set(corrections_indices)
                aug_to_corruption_indices[aug] = set(corruptions_indices)
                
        
#create_corrections_corruptions_plots(experiment_file_paths)
# Out:
# ERM_char_frequency_experiment_2/word_p_0.20/word_p_0.2nlp_random_word_delete_aug_size_1.npy
# ERM_char_frequency_experiment_2/word_p_0.05/word_p_0.05nlp_random_word_delete_aug_size_1.npy
# ERM_char_frequency_experiment_2/word_p_0.25/word_p_0.25nlp_random_word_delete_aug_size_1.npy
# ERM_char_frequency_experiment_2/word_p_0.10/word_p_0.1nlp_random_word_delete_aug_size_1.npy
# ERM_char_frequency_experiment_2/word_p_0.50/word_p_0.5nlp_random_word_delete_aug_size_1.npy
# ERM_char_frequency_experiment_2/word_p_0.75/word_p_0.75nlp_random_word_delete_aug_size_1.npy

# %%
create_heatmap(aug_to_correction_indices)
# Out:
# [[1.0, 0.16292798110979928, 0.14958569559529, 0.14319157237612173, 0.12171344165435746, 0.12197632527020072], [0.16292798110979928, 1.0, 0.21635569670504168, 0.2113997113997114, 0.19282891022021456, 0.18602922962595986], [0.14958569559529, 0.21635569670504168, 1.0, 0.2750316856780735, 0.27104989604989604, 0.27429906542056076], [0.14319157237612173, 0.2113997113997114, 0.2750316856780735, 1.0, 0.3083522583901085, 0.33178869323447635], [0.12171344165435746, 0.19282891022021456, 0.27104989604989604, 0.3083522583901085, 1.0, 0.4918809201623816], [0.12197632527020072, 0.18602922962595986, 0.27429906542056076, 0.33178869323447635, 0.4918809201623816, 1.0]]

# %%
create_heatmap(aug_to_corruption_indices, corrections = False)
# Out:
# [[1.0, 0.1516360734237829, 0.11544671689989236, 0.11080835603996367, 0.08353121944405643, 0.07331665397585119], [0.1516360734237829, 1.0, 0.14808531265147842, 0.14107365792759052, 0.11886893594210668, 0.10536884379623758], [0.11544671689989236, 0.14808531265147842, 1.0, 0.19197454481173767, 0.18999256873916273, 0.18507281553398058], [0.11080835603996367, 0.14107365792759052, 0.19197454481173767, 1.0, 0.23156517602283538, 0.2315976682146033], [0.08353121944405643, 0.11886893594210668, 0.18999256873916273, 0.23156517602283538, 1.0, 0.4135546334716459], [0.07331665397585119, 0.10536884379623758, 0.18507281553398058, 0.2315976682146033, 0.4135546334716459, 1.0]]

# %% [markdown]
# #### For del_10_words

# %%
aug_to_correction_indices = {}
aug_to_corruption_indices = {}

word_experiments_dir = 'ERM_word_frequency_experiment'


for filename in os.listdir(word_experiments_dir):
    full_path = './' + word_experiments_dir + '/' + filename

    if os.path.isfile(full_path) and full_path[-4:] == '.npy':
        corrections_corruptions_dict = calculate_corrections_corruptions(full_path, './ERM_predictions/bert.npy')
        
        num_corrections = corrections_corruptions_dict['num_corrections']
        num_corruptions = corrections_corruptions_dict['num_corruptions']
        
        corrections_indices = corrections_corruptions_dict['corrections_indices']
        corruptions_indices = corrections_corruptions_dict['corruptions_indices']
        
        assert num_corrections == len(corrections_indices), "number of corrections does not match indices provided"
        assert num_corruptions == len(corruptions_indices), "number of corruptions does not match indices provided"
        
        aug = int(full_path.split('/')[-1].split('.')[0].split('_')[-1])
        aug_to_correction_indices[aug] = set(corrections_indices)
        aug_to_corruption_indices[aug] = set(corruptions_indices)

# %%
create_heatmap(aug_to_correction_indices)
# Out:
# [[1.0, 0.18005071851225699, 0.1720183486238532, 0.15478615071283094, 0.15259348612786489, 0.14632735685367265, 0.13319126265316994, 0.13969849246231156, 0.13575525812619502, 0.12934631432545202], [0.18005071851225699, 1.0, 0.22611464968152867, 0.22183304144775248, 0.2328693790149893, 0.23068947641264903, 0.20873320537428022, 0.22807017543859648, 0.21403508771929824, 0.21217316759537078], [0.1720183486238532, 0.22611464968152867, 1.0, 0.250701065619742, 0.2675324675324675, 0.27461928934010155, 0.2557919621749409, 0.26790571169537625, 0.25757575757575757, 0.2542301184433164], [0.15478615071283094, 0.22183304144775248, 0.250701065619742, 1.0, 0.2703360935216756, 0.2708728652751423, 0.28305315765561107, 0.2752688172043011, 0.27775467775467777, 0.27877551020408164], [0.15259348612786489, 0.2328693790149893, 0.2675324675324675, 0.2703360935216756, 1.0, 0.3054676909173068, 0.2894177645558861, 0.3185215946843854, 0.3142514011208967, 0.3114947038054139], [0.14632735685367265, 0.23068947641264903, 0.27461928934010155, 0.2708728652751423, 0.3054676909173068, 1.0, 0.30902192242833054, 0.3314191960623462, 0.3262158956109134, 0.3377742946708464], [0.13319126265316994, 0.20873320537428022, 0.2557919621749409, 0.28305315765561107, 0.2894177645558861, 0.30902192242833054, 1.0, 0.3334644121116791, 0.34421820975797157, 0.337467117624953], [0.13969849246231156, 0.22807017543859648, 0.26790571169537625, 0.2752688172043011, 0.3185215946843854, 0.3314191960623462, 0.3334644121116791, 1.0, 0.35719612229679343, 0.36884942656307806], [0.13575525812619502, 0.21403508771929824, 0.25757575757575757, 0.27775467775467777, 0.3142514011208967, 0.3262158956109134, 0.34421820975797157, 0.35719612229679343, 1.0, 0.3802102210945995], [0.12934631432545202, 0.21217316759537078, 0.2542301184433164, 0.27877551020408164, 0.3114947038054139, 0.3377742946708464, 0.337467117624953, 0.36884942656307806, 0.3802102210945995, 1.0]]

# %%
create_heatmap(aug_to_corruption_indices, corrections = False)
# Out:
# [[1.0, 0.1730458221024259, 0.1435490973139586, 0.14193056085463562, 0.13443396226415094, 0.13623725671918444, 0.11830985915492957, 0.11488923235445647, 0.10970258410531449, 0.10989776951672862], [0.1730458221024259, 1.0, 0.20918367346938777, 0.2136125654450262, 0.18346650276582668, 0.1976978417266187, 0.1880501467057882, 0.17941176470588235, 0.16980255516840884, 0.1704115684093437], [0.1435490973139586, 0.20918367346938777, 1.0, 0.22810333963453056, 0.2357535435348568, 0.23066595059076261, 0.22734138972809667, 0.21471680594243267, 0.21563822677656494, 0.21592124973250587], [0.14193056085463562, 0.2136125654450262, 0.22810333963453056, 1.0, 0.2646979138444866, 0.26274410347451177, 0.2643319740945071, 0.26041200179131213, 0.26169433067471437, 0.2537128712871287], [0.13443396226415094, 0.18346650276582668, 0.2357535435348568, 0.2646979138444866, 1.0, 0.298011639185257, 0.29561624971310535, 0.2962643057654934, 0.29513311148086524, 0.2966237942122186], [0.13623725671918444, 0.1976978417266187, 0.23066595059076261, 0.26274410347451177, 0.298011639185257, 1.0, 0.306140350877193, 0.30914368650217705, 0.31894290901755096, 0.31371406371406374], [0.11830985915492957, 0.1880501467057882, 0.22734138972809667, 0.2643319740945071, 0.29561624971310535, 0.306140350877193, 1.0, 0.3318548387096774, 0.3262135922330097, 0.32612781954887216], [0.11488923235445647, 0.17941176470588235, 0.21471680594243267, 0.26041200179131213, 0.2962643057654934, 0.30914368650217705, 0.3318548387096774, 1.0, 0.3518901636261049, 0.3566983894582723], [0.10970258410531449, 0.16980255516840884, 0.21563822677656494, 0.26169433067471437, 0.29513311148086524, 0.31894290901755096, 0.3262135922330097, 0.3518901636261049, 1.0, 0.3701112307140294], [0.10989776951672862, 0.1704115684093437, 0.21592124973250587, 0.2537128712871287, 0.2966237942122186, 0.31371406371406374, 0.32612781954887216, 0.3566983894582723, 0.3701112307140294, 1.0]]

# %% [markdown]
# ## 10-word deletion correction/corruption length analysis:

# %%
del_10_corrections_comment_length = []

for comment in del_10_corrections_inputs[0]:
    comment_length = len(comment.split())
    del_10_corrections_comment_length.append(comment_length)
    

q10, q90 = np.percentile(del_10_corrections_comment_length, [10, 90])
print(q10)
print(q90)
bin_width = 2 * (q90 - q10) * len(del_10_corrections_comment_length) ** (-1/3)
bins = round((max(del_10_corrections_comment_length) - min(del_10_corrections_comment_length)) / bin_width)
print("Freedman–Diaconis number of bins:", bins)
plt.hist(del_10_corrections_comment_length, bins=bins)
plt.ylim(0, 1000)

# %%
del_10_corruptions_comment_length = []

for comment in del_10_corruptions_inputs[0]:
    comment_length = len(comment.split())
    del_10_corruptions_comment_length.append(comment_length)
    

q10, q90 = np.percentile(del_10_corruptions_comment_length, [10, 90])
print(q10)
print(q90)
bin_width = 2 * (q90 - q10) * len(del_10_corruptions_comment_length) ** (-1/3)
bins = round((max(del_10_corruptions_comment_length) - min(del_10_corruptions_comment_length)) / bin_width)
print("Freedman–Diaconis number of bins:", bins)
plt.hist(del_10_corruptions_comment_length, bins=bins)
plt.ylim(0, 1000)

# %%
char_experiments_dir = 'ERM_char_frequency_experiment'

experiment_file_paths = []

for filename in os.listdir(word_experiments_dir):
    full_path = './' + word_experiments_dir + '/' + filename

    if os.path.isfile(full_path):
        experiment_file_paths.append(full_path)
        
create_corrections_corruptions_plots(experiment_file_paths)

# %%
with open('nlp_ocr_ERM_predictions.npy', 'rb') as g:#, open('nlp_random_char_insert_ERM_predictions.npy', 'rb') as h:
    a = np.load(g)
    #b = np.load(g)
    #c = np.load(h)
    
print(a)#, b, c)
# Out:
# [[0.45754883 0.54245126]]

# %%
train_data[1]

# %%
#len(batch[1])
#batch[1]
batch[2]

# batch[0] is array of input features
# batch[1] is array of labels
# batch[2] is array of metadata
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-59c28442ddfd> in <module>
#       1 #len(batch[1])
#       2 #batch[1]
# ----> 3 batch[2]
#       4
#       5 # batch[0] is array of input features
#
# NameError: name 'batch' is not defined

# %%
np.shape(batch[0][0])
# Out:
# torch.Size([300, 2])

# %%
np.shape(batch[0][0])

np.shape(torch.unsqueeze(batch[0][0], 0))
# Out:
# torch.Size([1, 300, 2])

# %%
x = model.model(torch.unsqueeze(batch[0][0], 0).cuda())

# Outputting before transforming to measure toxicity

# Apply softmax to normalize and sum to 1

# Save predictions while iterating through samples into .npy or pickl (np.save)

# %%
softmax_prediction = sp.special.softmax(x.cpu().detach().numpy())
softmax_prediction.tolist()
# Out:
# [[0.4568701684474945, 0.5431299209594727]]

# %%
datasets[split]
# Out:
# {'dataset': <wilds.datasets.wilds_dataset.WILDSSubset at 0x7fa531852a58>,
#  'loader': <torch.utils.data.dataloader.DataLoader at 0x7fa531852a90>,
#  'split': 'test',
#  'name': 'Test',
#  'verbose': False}

# %%
datasets['val']['loader']

# %%
import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.sentence as nas
import nlpaug.flow as nafc
import os

text = "California carolina between buffalo yorkies elephant alphabet"

# %%
import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.sentence as nas
import nlpaug.flow as nafc
import os

text = "The quick brown fox jumped over the lazy dog."
aug = nac.RandomCharAug(action = 'delete'
                       , aug_char_min = 1
                       , aug_char_max = 1
                       , aug_char_p = 1
                       , aug_word_p = 0.3
                       , aug_word_min = 1
                       , aug_word_max = None)

augmented_text = aug.augment(text, n = 10)

augmented_text
# Out:
# ['The quick rown fox jumped ver the azy dog.',
#  'The quck brown fox jumed over the lay dog.',
#  'The quck brown fox jumped ove the lzy dog.',
#  'The quick bron fox jumped oer the lzy dog.',
#  'The quck rown fox jumped over the lay dog.',
#  'The quik bown fox jumped over the lay dog.',
#  'The quic rown fox jumped over the azy dog.',
#  'The quick bron fox jumped ovr the azy dog.',
#  'The quick brwn fox jumped ove the azy dog.',
#  'The quck brown fox umped over the azy dog.']

# %%
aug = nac.RandomCharAug(action = 'delete'
                       , aug_char_min = 2
                       , aug_char_max = 2
                       , aug_char_p = 0.5
                       , aug_word_p = 1
                       , aug_word_min = 1
                       , aug_word_max = 1)

augmented_text = aug.augment(text, n = 2)

augmented_text
# Out:
# ['California carolina between bufao yorkies elephant alphabet',
#  'California carolina between buffalo yorkies elephant phabet']

# %%
aug = nac.RandomCharAug(action = 'delete'
                       , aug_char_min = 1
                       , aug_char_max = 100
                       , aug_char_p = 0.5
                       , aug_word_p = 0.5
                       , aug_word_min = 20
                       , aug_word_max = 20)
                       #, min_char = 0)

augmented_text = aug.augment(text, n = 2)

augmented_text
# Out:
# ['The ick brw fox hi med er the zy dog.',
#  'The uik ron fox hi mpe ov the az dog.']

# %%
aug = nac.RandomCharAug(action = 'delete'
                       , aug_char_min = 3
                       , aug_char_max = 3
                        #$, aug_char_p = 1
                       #, aug_word_p = 1
                       , aug_word_min = 3
                       , aug_word_max = 3)

augmented_text = aug.augment(text, n = 2)

augmented_text
# Out:
# ['The quick wn fox jumped v the a dog.',
#  'The qc wn fox jumped r the lazy dog.']

# %%
text
# Out:
# 'The quick brown fox jumped over the lazy dog.'

# %%
aug = naw.RandomWordAug(action = 'delete'
                               , aug_min = 500
                               , aug_max = None 
                               , aug_p = 0.1)

augmented_text = aug.augment(text, n = 1)

augmented_text
# Out:
# 'Quick.'

# %%
aug = naw.RandomWordAug(action = 'delete'
                               , aug_min = 5
                               , aug_max = 5
                               , aug_p = 1)

augmented_text = aug.augment(text, n = 1)

augmented_text
# Out:
# 'Quick brown fox the dog.'

# %%
'''
INSPECTION OF CIVIL COMMENTS DATA INPUT
'''

word_histogram = []
char_histogram = []

full_dataset_inputs = full_dataset._text_array

for data in full_dataset_inputs:
    words_list = data.split()
    num_words = len(words_list)
    
    for word in words_list:
        num_char = len(word)
        char_histogram.append(num_char)
    
    word_histogram.append(num_words)

# %%
q10, q90 = np.percentile(word_histogram, [10, 90])
print(q10)
print(q90)
bin_width = 2 * (q90 - q10) * len(word_histogram) ** (-1/3)
bins = round((max(word_histogram) - min(word_histogram)) / bin_width)
print("Freedman–Diaconis number of bins:", bins)
plt.hist(word_histogram, bins=bins);
# Out:
# 11.0
# 147.0
# Freedman–Diaconis number of bins: 88

# %%
q25, q75 = np.percentile(word_histogram, [25, 75])
bin_width = 2 * (q75 - q25) * len(word_histogram) ** (-1/3)
bins = round((max(word_histogram) - min(word_histogram)) / bin_width)
print("Freedman–Diaconis number of bins:", bins)
plt.hist(word_histogram, bins=bins);
# Out:
# Freedman–Diaconis number of bins: 179

# %%
min(word_histogram)
# Out:
# 1

# %%
max(word_histogram)
# Out:
# 315

# %%
for data in full_dataset_inputs:
    if len(data.split()) == 315:
        print(data)
# Out:
# As usual WW plumbing the depths for deeper meaning ... that is unless it involves an issue on which they disagree then it is ridicule 24/7.   Clever creating the Bundyland series complete with cartoon banner.  Set the tone for the level of journalism to expect ... journalism ?  ... fatastisticism.
#
# I did notice you soft pedaling the ridicule of David Fry identifying him as troubled.  My guess is that has more to do with sympathy for his pot smoking withdrawl rants than respect for his politics.  Respect is never a factor with liberals as evidenced by your series of vapid caricatures.
#
# Did you happen to see the stories actual journalists did on Refuge mis-managment, fires, floods, and the millions of Carp that are harassing the birds away from the Bird Refuge?  The stories of arbitrary miss-management that are driving unemployment ever higher in eastern Oregon.  Curry County Sheriff turning in his badge in frustration for lack of resources dud to dwindling tax base engineered by arbitrary over reaching Federal Government policies.  Or how about the thousands of miles of roads proposed to be removed from Oregon wild lands, cutting off public and fire access?  What is the one issue the people of Oregon demand universally?  Access to the wild lands?  You are not reporting that it is being taken away.  More closed roads.  More illegal Federal Police, guns drawn, stops ... as reported by the Sheriff of Grant County.
#
# I suspect the real problem was real people you couldn't care less about were articulate, were actual victims, and made rational arguments you could not respond to.  The exact opposite of the great unbathed OWS movement, apart from the paid organizers, that held downtown Portland hostage and trashed 3 park blocks for 3 weeks.
#
# Shame on you.  You missed some really great stories and even greater people ... people who don't drink $5 cups of coffee.

# %%
full_dataset_inputs = full_dataset._text_array
len(full_dataset_inputs)
# Out:
# 448000

# %%
print(full_dataset_inputs[0])
# Out:
# OH yes - Were those evil Christian Missionaries (many of whom were slaughtered by the Indians, or lost their lives due to disease, starvation etc.) lumped in with those "genocidists" you mention ? (yes I did make up a word, just as you make up stories).

# %%
print(full_dataset_inputs[0].split())
# Out:
# ['OH', 'yes', '-', 'Were', 'those', 'evil', 'Christian', 'Missionaries', '(many', 'of', 'whom', 'were', 'slaughtered', 'by', 'the', 'Indians,', 'or', 'lost', 'their', 'lives', 'due', 'to', 'disease,', 'starvation', 'etc.)', 'lumped', 'in', 'with', 'those', '"genocidists"', 'you', 'mention', '?', '(yes', 'I', 'did', 'make', 'up', 'a', 'word,', 'just', 'as', 'you', 'make', 'up', 'stories).']

# %%
full_dataset_inputs = full_dataset._text_array

for i in range(5):
    data = full_dataset_inputs[i]
    print(data)
    print(data.split())

# %%
q25, q75 = np.percentile(char_histogram, [25, 75])
bin_width = 2 * (q75 - q25) * len(char_histogram) ** (-1/3)
bins = round((max(char_histogram) - min(char_histogram)) / bin_width)
print("Freedman–Diaconis number of bins:", bins)
plt.hist(char_histogram, bins=bins);
# Out:
# Freedman–Diaconis number of bins: 25037

# %%
print(q25)
print(q75)
# Out:
# 3.0
# 6.0

# %%
min(char_histogram)
# Out:
# 1

# %%
max(char_histogram)
# Out:
# 1891

# %%
for data in full_dataset_inputs:
    if len(data) == 1:
        print(data)
# Out:
# d
# .
# g
# ?
# ?
# ?
# .
# 🤔
# 😥
# ☺
# K
# ,
# .
# .
# 1
# r
# ?

# %%
for data in full_dataset_inputs:
    if len(data) == 1891:
        print(data)
# Out:
# As usual WW plumbing the depths for deeper meaning ... that is unless it involves an issue on which they disagree then it is ridicule 24/7.   Clever creating the Bundyland series complete with cartoon banner.  Set the tone for the level of journalism to expect ... journalism ?  ... fatastisticism.
#
# I did notice you soft pedaling the ridicule of David Fry identifying him as troubled.  My guess is that has more to do with sympathy for his pot smoking withdrawl rants than respect for his politics.  Respect is never a factor with liberals as evidenced by your series of vapid caricatures.
#
# Did you happen to see the stories actual journalists did on Refuge mis-managment, fires, floods, and the millions of Carp that are harassing the birds away from the Bird Refuge?  The stories of arbitrary miss-management that are driving unemployment ever higher in eastern Oregon.  Curry County Sheriff turning in his badge in frustration for lack of resources dud to dwindling tax base engineered by arbitrary over reaching Federal Government policies.  Or how about the thousands of miles of roads proposed to be removed from Oregon wild lands, cutting off public and fire access?  What is the one issue the people of Oregon demand universally?  Access to the wild lands?  You are not reporting that it is being taken away.  More closed roads.  More illegal Federal Police, guns drawn, stops ... as reported by the Sheriff of Grant County.
#
# I suspect the real problem was real people you couldn't care less about were articulate, were actual victims, and made rational arguments you could not respond to.  The exact opposite of the great unbathed OWS movement, apart from the paid organizers, that held downtown Portland hostage and trashed 3 park blocks for 3 weeks.
#
# Shame on you.  You missed some really great stories and even greater people ... people who don't drink $5 cups of coffee.

# %%
""" 
EXPERIMENT: IMPACT OF CHAR AUGMENTATION FREQUENCY ON ACCURACY
"""

char_augmentation = 'nlp_random_char_deletion'

for i in range(1, 5):
    predict_augmented_labels(char_augmentation, aug_size = i)

# %%
def create_char_exp_accuracy_graph(exp_folder, graph_type = 'bar'):
    
    aug_to_acc = []
    
    print(exp_folder)
    percent_words_modified = float(exp_folder.split('/')[-1].split('_')[-1])

    print(percent_words_modified)
    for filename in os.listdir(exp_folder):
        #print(filename)
        full_path = exp_folder + '/' + filename
        print(full_path)
        if os.path.isfile(full_path):
            accuracies = calculate_accuracy(full_path)
            num_char = filename[-5:-4] # HOW TO GET NUMBER OF CHARACTERS

            print(accuracies)
            for i in range(len(accuracies)):
                accuracy = accuracies[i]
                aug_dict = {"num_char_augmented":num_char, "accuracy": accuracy, "batch_num": i}
                aug_to_acc.append(aug_dict)

    
    print(aug_to_acc)
    acc_df = pd.DataFrame(aug_to_acc).sort_values('num_char_augmented', ascending = True)
    print(acc_df)
    
    fig, ax = plt.subplots()

    if graph_type == 'bar':
        p = sns.barplot(x = 'num_char_augmented', y = 'accuracy', data = acc_df, ci = 95, ax = ax)#, order = acc_df['augmentation'])
    
    elif graph_type == 'box':
        p = sns.boxplot(x = 'num_char_augmented', y = 'accuracy', data = acc_df, ax = ax)#, order = acc_df['augmentation'])


    min_value = acc_df.min()['accuracy']
    max_value = acc_df.max()['accuracy']

    ax.set_ylim(min_value - 0.02, min(1.0, max_value + 0.02))
    
    #print(p.containers[0])
    #p.bar_label(p.containers[0])
    show_values(p)
    plt.rcParams['figure.figsize'] = (30,10)
    
    print(percent_words_modified)
    title = str(percent_words_modified) + " of input modified with nlpaug_random_char_deletion"
    
    plt.title(title)
    plt.show()

# %%
def create_exp_accuracy_summary_plot(exp_folders):
    aug_to_acc = []
    hue_order = []
    

    for folder in exp_folders:
        percent_words_modified = float(folder.split('/')[-1].split('_')[-1]) # HOW TO GET PERC. WORDS
        hue_order.append(percent_words_modified)
        
        for filename in os.listdir(folder):
            print(filename)
            full_path = folder + '/' + filename
            
            if os.path.isfile(full_path):
                accuracies = calculate_accuracy(full_path)
                num_char = filename[-5:-4] # HOW TO GET NUMBER OF CHARACTERS

                for i in range(len(accuracies)):
                    accuracy = accuracies[i]
                    aug_dict = {"num_char_augmented":num_char, "accuracy": accuracy, "perc_words_augmented": percent_words_modified, "batch_num": i}
                    aug_to_acc.append(aug_dict)

    
    acc_df = pd.DataFrame(aug_to_acc).sort_values('num_char_augmented', ascending = True)
    print(acc_df)
    
    fig, ax = plt.subplots()

    p = sns.lineplot(data = acc_df, x = "num_char_augmented", y = "accuracy", hue = "perc_words_augmented", hue_order = hue_order, ax = ax)#, order = acc_df['augmentation'])
    
    min_value = acc_df.min()['accuracy']
    max_value = acc_df.max()['accuracy']

    ax.set_ylim(min_value - 0.02, min(1.0, max_value + 0.02))
    
    #ax.add_legend(label_order = exp_folders)
    
    #print(p.containers[0])
    #p.bar_label(p.containers[0])
    show_values(p)
    #plt.rcParams['figure.figsize'] = (20,10)
    
    print(percent_words_modified)
    title = "Impact of nlpaug_random_char_deletion augmentation intensity on predictive accuracy"
    
    plt.title(title)
    plt.show()

# %%
create_char_exp_accuracy_graph('ERM_char_frequency_experiment_2/word_p_0.25')
# Out:
# ERM_char_frequency_experiment_2/word_p_0.25
# word_p_0.25nlp_random_word_delete_aug_size_2.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.25nlp_random_word_delete_aug_size_4.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.25nlp_random_word_delete_aug_size_3.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.25nlp_random_word_delete_aug_size_1.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
#    num_char_augmented  accuracy  batch_num
# 39                  1  0.915095          9
# 37                  1  0.914908          7
# 36                  1  0.914880          6
# 35                  1  0.914740          5
# 34                  1  0.914683          4
# 33                  1  0.914982          3
# 32                  1  0.914936          2
# 31                  1  0.914562          1
# 30                  1  0.914758          0
# 38                  1  0.915618          8
# 0                   2  0.914431          0
# 1                   2  0.913488          1
# 2                   2  0.914114          2
# 3                   2  0.914263          3
# 4                   2  0.914235          4
# 5                   2  0.914029          5
# 6                   2  0.913833          6
# 7                   2  0.914272          7
# 9                   2  0.914244          9
# 8                   2  0.914263          8
# 25                  3  0.914048          5
# 27                  3  0.914198          7
# 26                  3  0.914590          6
# 24                  3  0.913889          4
# 20                  3  0.914441          0
# 22                  3  0.914637          2
# 21                  3  0.913553          1
# 28                  3  0.914515          8
# 23                  3  0.914627          3
# 29                  3  0.914244          9
# 11                  4  0.915057          1
# 18                  4  0.914954          8
# 17                  4  0.914973          7
# 16                  4  0.914824          6
# 15                  4  0.914852          5
# 14                  4  0.914665          4
# 13                  4  0.914908          3
# 12                  4  0.914982          2
# 10                  4  0.915076          0
# 19                  4  0.916169          9
# 0.25

# %%
create_char_exp_accuracy_graph('ERM_char_frequency_experiment_2/word_p_0.50')
# Out:
# ERM_char_frequency_experiment_2/word_p_0.50
# 0.5
# ERM_char_frequency_experiment_2/word_p_0.50/word_p_0.5nlp_random_word_delete_aug_size_4.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# [0.9006120065405279, 0.9007895351553376, 0.8999953281943471, 0.9007988787666433, 0.8996028965195048, 0.8993973370707778, 0.9008549404344779, 0.9005372576500817, 0.9004251343144125, 0.9006400373744452]
# ERM_char_frequency_experiment_2/word_p_0.50/word_p_0.5nlp_random_word_delete_aug_size_3.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# [0.9006120065405279, 0.9004344779257183, 0.9010418126605934, 0.9004625087596356, 0.901013781826676, 0.9010231254379818, 0.9009764073814529, 0.9017332398972203, 0.9003784162578836, 0.9014529315580472]
# ERM_char_frequency_experiment_2/word_p_0.50/word_p_0.5nlp_random_word_delete_aug_size_2.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# [0.9008829712683952, 0.9007054426535857, 0.9006120065405279, 0.9006960990422799, 0.9007521607101144, 0.8999766409717356, 0.9009390329362299, 0.9007147862648914, 0.900079420696099, 0.9007241298761971]
# ERM_char_frequency_experiment_2/word_p_0.50/word_p_0.5nlp_random_word_delete_aug_size_1.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# [0.8999672973604298, 0.8998084559682317, 0.8992478392898855, 0.8998551740247606, 0.9000513898621817, 0.8998832048586779, 0.9002943237561317, 0.9004344779257183, 0.8995842092968932, 0.9001074515300164]
# [{'num_char_augmented': '4', 'accuracy': 0.9006120065405279, 'batch_num': 0}, {'num_char_augmented': '4', 'accuracy': 0.9007895351553376, 'batch_num': 1}, {'num_char_augmented': '4', 'accuracy': 0.8999953281943471, 'batch_num': 2}, {'num_char_augmented': '4', 'accuracy': 0.9007988787666433, 'batch_num': 3}, {'num_char_augmented': '4', 'accuracy': 0.8996028965195048, 'batch_num': 4}, {'num_char_augmented': '4', 'accuracy': 0.8993973370707778, 'batch_num': 5}, {'num_char_augmented': '4', 'accuracy': 0.9008549404344779, 'batch_num': 6}, {'num_char_augmented': '4', 'accuracy': 0.9005372576500817, 'batch_num': 7}, {'num_char_augmented': '4', 'accuracy': 0.9004251343144125, 'batch_num': 8}, {'num_char_augmented': '4', 'accuracy': 0.9006400373744452, 'batch_num': 9}, {'num_char_augmented': '3', 'accuracy': 0.9006120065405279, 'batch_num': 0}, {'num_char_augmented': '3', 'accuracy': 0.9004344779257183, 'batch_num': 1}, {'num_char_augmented': '3', 'accuracy': 0.9010418126605934, 'batch_num': 2}, {'num_char_augmented': '3', 'accuracy': 0.9004625087596356, 'batch_num': 3}, {'num_char_augmented': '3', 'accuracy': 0.901013781826676, 'batch_num': 4}, {'num_char_augmented': '3', 'accuracy': 0.9010231254379818, 'batch_num': 5}, {'num_char_augmented': '3', 'accuracy': 0.9009764073814529, 'batch_num': 6}, {'num_char_augmented': '3', 'accuracy': 0.9017332398972203, 'batch_num': 7}, {'num_char_augmented': '3', 'accuracy': 0.9003784162578836, 'batch_num': 8}, {'num_char_augmented': '3', 'accuracy': 0.9014529315580472, 'batch_num': 9}, {'num_char_augmented': '2', 'accuracy': 0.9008829712683952, 'batch_num': 0}, {'num_char_augmented': '2', 'accuracy': 0.9007054426535857, 'batch_num': 1}, {'num_char_augmented': '2', 'accuracy': 0.9006120065405279, 'batch_num': 2}, {'num_char_augmented': '2', 'accuracy': 0.9006960990422799, 'batch_num': 3}, {'num_char_augmented': '2', 'accuracy': 0.9007521607101144, 'batch_num': 4}, {'num_char_augmented': '2', 'accuracy': 0.8999766409717356, 'batch_num': 5}, {'num_char_augmented': '2', 'accuracy': 0.9009390329362299, 'batch_num': 6}, {'num_char_augmented': '2', 'accuracy': 0.9007147862648914, 'batch_num': 7}, {'num_char_augmented': '2', 'accuracy': 0.900079420696099, 'batch_num': 8}, {'num_char_augmented': '2', 'accuracy': 0.9007241298761971, 'batch_num': 9}, {'num_char_augmented': '1', 'accuracy': 0.8999672973604298, 'batch_num': 0}, {'num_char_augmented': '1', 'accuracy': 0.8998084559682317, 'batch_num': 1}, {'num_char_augmented': '1', 'accuracy': 0.8992478392898855, 'batch_num': 2}, {'num_char_augmented': '1', 'accuracy': 0.8998551740247606, 'batch_num': 3}, {'num_char_augmented': '1', 'accuracy': 0.9000513898621817, 'batch_num': 4}, {'num_char_augmented': '1', 'accuracy': 0.8998832048586779, 'batch_num': 5}, {'num_char_augmented': '1', 'accuracy': 0.9002943237561317, 'batch_num': 6}, {'num_char_augmented': '1', 'accuracy': 0.9004344779257183, 'batch_num': 7}, {'num_char_augmented': '1', 'accuracy': 0.8995842092968932, 'batch_num': 8}, {'num_char_augmented': '1', 'accuracy': 0.9001074515300164, 'batch_num': 9}]
#    num_char_augmented  accuracy  batch_num
# 39                  1  0.900107          9
# 30                  1  0.899967          0
# 31                  1  0.899808          1
# 32                  1  0.899248          2
# 33                  1  0.899855          3
# 38                  1  0.899584          8
# 35                  1  0.899883          5
# 36                  1  0.900294          6
# 37                  1  0.900434          7
# 34                  1  0.900051          4
# 20                  2  0.900883          0
# 28                  2  0.900079          8
# 27                  2  0.900715          7
# 26                  2  0.900939          6
# 25                  2  0.899977          5
# 24                  2  0.900752          4
# 23                  2  0.900696          3
# 22                  2  0.900612          2
# 21                  2  0.900705          1
# 29                  2  0.900724          9
# 19                  3  0.901453          9
# 17                  3  0.901733          7
# 16                  3  0.900976          6
# 15                  3  0.901023          5
# 14                  3  0.901014          4
# 13                  3  0.900463          3
# 12                  3  0.901042          2
# 11                  3  0.900434          1
# 10                  3  0.900612          0
# 18                  3  0.900378          8
# 1                   4  0.900790          1
# 2                   4  0.899995          2
# 3                   4  0.900799          3
# 4                   4  0.899603          4
# 8                   4  0.900425          8
# 6                   4  0.900855          6
# 7                   4  0.900537          7
# 9                   4  0.900640          9
# 5                   4  0.899397          5
# 0                   4  0.900612          0
# 0.5

# %%
create_char_exp_accuracy_graph('ERM_char_frequency_experiment_2/word_p_0.75')
# Out:
# ERM_char_frequency_experiment_2/word_p_0.75
# word_p_0.75nlp_random_word_delete_aug_size_1.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.75nlp_random_word_delete_aug_size_2.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.75nlp_random_word_delete_aug_size_3.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.75nlp_random_word_delete_aug_size_4.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
#    num_char_augmented  accuracy  batch_num
# 0                   1  0.889054          0
# 1                   1  0.887849          1
# 2                   1  0.888082          2
# 3                   1  0.888204          3
# 4                   1  0.887811          4
# 5                   1  0.888736          5
# 6                   1  0.888456          6
# 7                   1  0.888923          7
# 8                   1  0.888110          8
# 9                   1  0.888820          9
# 18                  2  0.888914          8
# 17                  2  0.888493          7
# 16                  2  0.887830          6
# 15                  2  0.887979          5
# 19                  2  0.889306          9
# 13                  2  0.888110          3
# 12                  2  0.889175          2
# 11                  2  0.888671          1
# 10                  2  0.888643          0
# 14                  2  0.888755          4
# 29                  3  0.888073          9
# 28                  3  0.888064          8
# 26                  3  0.888811          6
# 25                  3  0.888577          5
# 27                  3  0.888428          7
# 23                  3  0.887708          3
# 22                  3  0.888671          2
# 21                  3  0.888437          1
# 20                  3  0.887933          0
# 24                  3  0.887923          4
# 38                  4  0.888876          8
# 30                  4  0.887886          0
# 31                  4  0.887774          1
# 32                  4  0.888633          2
# 33                  4  0.887288          3
# 34                  4  0.888876          4
# 35                  4  0.888792          5
# 36                  4  0.888876          6
# 37                  4  0.888475          7
# 39                  4  0.889166          9
# 0.75

# %%
experiment_folders = [
                     'ERM_char_frequency_experiment_2/word_p_0.25',
                     'ERM_char_frequency_experiment_2/word_p_0.50',
                     'ERM_char_frequency_experiment_2/word_p_0.75',
                     ]

create_exp_accuracy_summary_plot(experiment_folders)
# Out:
# word_p_0.25nlp_random_word_delete_aug_size_2.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.25nlp_random_word_delete_aug_size_4.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.25nlp_random_word_delete_aug_size_3.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.25nlp_random_word_delete_aug_size_1.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.5nlp_random_word_delete_aug_size_4.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.5nlp_random_word_delete_aug_size_3.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.5nlp_random_word_delete_aug_size_2.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.5nlp_random_word_delete_aug_size_1.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.75nlp_random_word_delete_aug_size_1.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.75nlp_random_word_delete_aug_size_2.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.75nlp_random_word_delete_aug_size_3.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.75nlp_random_word_delete_aug_size_4.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
#     num_char_augmented  accuracy  perc_words_augmented  batch_num
# 34                   1  0.914459                  0.25          4
# 82                   1  0.888970                  0.75          2
# 83                   1  0.888605                  0.75          3
# 84                   1  0.887531                  0.75          4
# 85                   1  0.888045                  0.75          5
# ..                 ...       ...                   ...        ...
# 44                   4  0.900425                  0.50          4
# 45                   4  0.900575                  0.50          5
# 46                   4  0.899631                  0.50          6
# 15                   4  0.914553                  0.25          5
# 119                  4  0.887867                  0.75          9
#
# [120 rows x 4 columns]
# 0.75

# %%
experiment_folders = [
                     'ERM_char_frequency_experiment_2/word_p_0.05',
                     'ERM_char_frequency_experiment_2/word_p_0.10',
                     'ERM_char_frequency_experiment_2/word_p_0.20',
                     'ERM_char_frequency_experiment_2/word_p_0.25',
                     'ERM_char_frequency_experiment_2/word_p_0.50',
                     'ERM_char_frequency_experiment_2/word_p_0.75',
                     ]

create_exp_accuracy_summary_plot(experiment_folders)
# Out:
# word_p_0.05nlp_random_word_delete_aug_size_3.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.05nlp_random_word_delete_aug_size_2.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.05nlp_random_word_delete_aug_size_4.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.05nlp_random_word_delete_aug_size_1.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.1nlp_random_word_delete_aug_size_2.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.1nlp_random_word_delete_aug_size_1.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.1nlp_random_word_delete_aug_size_3.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.1nlp_random_word_delete_aug_size_4.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.2nlp_random_word_delete_aug_size_2.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.2nlp_random_word_delete_aug_size_1.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.2nlp_random_word_delete_aug_size_4.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.2nlp_random_word_delete_aug_size_3.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.25nlp_random_word_delete_aug_size_2.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.25nlp_random_word_delete_aug_size_4.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.25nlp_random_word_delete_aug_size_3.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.25nlp_random_word_delete_aug_size_1.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.5nlp_random_word_delete_aug_size_4.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.5nlp_random_word_delete_aug_size_3.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.5nlp_random_word_delete_aug_size_2.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.5nlp_random_word_delete_aug_size_1.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.75nlp_random_word_delete_aug_size_1.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.75nlp_random_word_delete_aug_size_2.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.75nlp_random_word_delete_aug_size_3.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# word_p_0.75nlp_random_word_delete_aug_size_4.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
#     num_char_augmented  accuracy  perc_words_augmented  batch_num
# 198                  1  0.899893                  0.50          8
# 200                  1  0.888400                  0.75          0
# 201                  1  0.888512                  0.75          1
# 202                  1  0.888092                  0.75          2
# 203                  1  0.888138                  0.75          3
# ..                 ...       ...                   ...        ...
# 108                  4  0.918458                  0.20          8
# 109                  4  0.918888                  0.20          9
# 238                  4  0.888456                  0.75          8
# 71                   4  0.922541                  0.10          1
# 239                  4  0.888288                  0.75          9
#
# [240 rows x 4 columns]
# 0.75

# %%
create_char_exp_accuracy_graph('ERM_char_frequency_experiment_2/word_p_0.05')
# Out:
# ERM_char_frequency_experiment_2/word_p_0.05
# 0.05
# ERM_char_frequency_experiment_2/word_p_0.05/word_p_0.05nlp_random_word_delete_aug_size_3.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# [0.9237935061901424, 0.9238215370240598, 0.9237935061901424, 0.9242046250875964, 0.9241392198084559, 0.9238869423032002, 0.9236253211866386, 0.9241485634197617, 0.9237935061901424, 0.9238589114692829]
# ERM_char_frequency_experiment_2/word_p_0.05/word_p_0.05nlp_random_word_delete_aug_size_2.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# [0.9243074048119598, 0.9240644709180098, 0.9244849334267694, 0.9237000700770848, 0.9236346647979444, 0.9244195281476291, 0.9239056295258117, 0.9243167484232656, 0.9233263256248541, 0.9243260920345714]
# ERM_char_frequency_experiment_2/word_p_0.05/word_p_0.05nlp_random_word_delete_aug_size_4.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# [0.9247372109320252, 0.9248960523242233, 0.9255220742817099, 0.9244569025928522, 0.9249614576033637, 0.9249334267694463, 0.9248586778790002, 0.9237094136883905, 0.9248026162111657, 0.9245409950946041]
# ERM_char_frequency_experiment_2/word_p_0.05/word_p_0.05nlp_random_word_delete_aug_size_1.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# [0.9238215370240598, 0.9231955150665733, 0.9242700303667367, 0.9233263256248541, 0.9234197617379117, 0.9241952814762906, 0.9237467881336137, 0.9234664797944405, 0.9235225414622752, 0.9235599159074982]
# [{'num_char_augmented': '3', 'accuracy': 0.9237935061901424, 'batch_num': 0}, {'num_char_augmented': '3', 'accuracy': 0.9238215370240598, 'batch_num': 1}, {'num_char_augmented': '3', 'accuracy': 0.9237935061901424, 'batch_num': 2}, {'num_char_augmented': '3', 'accuracy': 0.9242046250875964, 'batch_num': 3}, {'num_char_augmented': '3', 'accuracy': 0.9241392198084559, 'batch_num': 4}, {'num_char_augmented': '3', 'accuracy': 0.9238869423032002, 'batch_num': 5}, {'num_char_augmented': '3', 'accuracy': 0.9236253211866386, 'batch_num': 6}, {'num_char_augmented': '3', 'accuracy': 0.9241485634197617, 'batch_num': 7}, {'num_char_augmented': '3', 'accuracy': 0.9237935061901424, 'batch_num': 8}, {'num_char_augmented': '3', 'accuracy': 0.9238589114692829, 'batch_num': 9}, {'num_char_augmented': '2', 'accuracy': 0.9243074048119598, 'batch_num': 0}, {'num_char_augmented': '2', 'accuracy': 0.9240644709180098, 'batch_num': 1}, {'num_char_augmented': '2', 'accuracy': 0.9244849334267694, 'batch_num': 2}, {'num_char_augmented': '2', 'accuracy': 0.9237000700770848, 'batch_num': 3}, {'num_char_augmented': '2', 'accuracy': 0.9236346647979444, 'batch_num': 4}, {'num_char_augmented': '2', 'accuracy': 0.9244195281476291, 'batch_num': 5}, {'num_char_augmented': '2', 'accuracy': 0.9239056295258117, 'batch_num': 6}, {'num_char_augmented': '2', 'accuracy': 0.9243167484232656, 'batch_num': 7}, {'num_char_augmented': '2', 'accuracy': 0.9233263256248541, 'batch_num': 8}, {'num_char_augmented': '2', 'accuracy': 0.9243260920345714, 'batch_num': 9}, {'num_char_augmented': '4', 'accuracy': 0.9247372109320252, 'batch_num': 0}, {'num_char_augmented': '4', 'accuracy': 0.9248960523242233, 'batch_num': 1}, {'num_char_augmented': '4', 'accuracy': 0.9255220742817099, 'batch_num': 2}, {'num_char_augmented': '4', 'accuracy': 0.9244569025928522, 'batch_num': 3}, {'num_char_augmented': '4', 'accuracy': 0.9249614576033637, 'batch_num': 4}, {'num_char_augmented': '4', 'accuracy': 0.9249334267694463, 'batch_num': 5}, {'num_char_augmented': '4', 'accuracy': 0.9248586778790002, 'batch_num': 6}, {'num_char_augmented': '4', 'accuracy': 0.9237094136883905, 'batch_num': 7}, {'num_char_augmented': '4', 'accuracy': 0.9248026162111657, 'batch_num': 8}, {'num_char_augmented': '4', 'accuracy': 0.9245409950946041, 'batch_num': 9}, {'num_char_augmented': '1', 'accuracy': 0.9238215370240598, 'batch_num': 0}, {'num_char_augmented': '1', 'accuracy': 0.9231955150665733, 'batch_num': 1}, {'num_char_augmented': '1', 'accuracy': 0.9242700303667367, 'batch_num': 2}, {'num_char_augmented': '1', 'accuracy': 0.9233263256248541, 'batch_num': 3}, {'num_char_augmented': '1', 'accuracy': 0.9234197617379117, 'batch_num': 4}, {'num_char_augmented': '1', 'accuracy': 0.9241952814762906, 'batch_num': 5}, {'num_char_augmented': '1', 'accuracy': 0.9237467881336137, 'batch_num': 6}, {'num_char_augmented': '1', 'accuracy': 0.9234664797944405, 'batch_num': 7}, {'num_char_augmented': '1', 'accuracy': 0.9235225414622752, 'batch_num': 8}, {'num_char_augmented': '1', 'accuracy': 0.9235599159074982, 'batch_num': 9}]
#    num_char_augmented  accuracy  batch_num
# 39                  1  0.923560          9
# 37                  1  0.923466          7
# 36                  1  0.923747          6
# 35                  1  0.924195          5
# 34                  1  0.923420          4
# 33                  1  0.923326          3
# 32                  1  0.924270          2
# 31                  1  0.923196          1
# 30                  1  0.923822          0
# 38                  1  0.923523          8
# 18                  2  0.923326          8
# 17                  2  0.924317          7
# 16                  2  0.923906          6
# 15                  2  0.924420          5
# 19                  2  0.924326          9
# 13                  2  0.923700          3
# 12                  2  0.924485          2
# 11                  2  0.924064          1
# 10                  2  0.924307          0
# 14                  2  0.923635          4
# 1                   3  0.923822          1
# 2                   3  0.923794          2
# 3                   3  0.924205          3
# 4                   3  0.924139          4
# 5                   3  0.923887          5
# 6                   3  0.923625          6
# 7                   3  0.924149          7
# 8                   3  0.923794          8
# 0                   3  0.923794          0
# 9                   3  0.923859          9
# 29                  4  0.924541          9
# 26                  4  0.924859          6
# 25                  4  0.924933          5
# 24                  4  0.924961          4
# 23                  4  0.924457          3
# 22                  4  0.925522          2
# 21                  4  0.924896          1
# 20                  4  0.924737          0
# 28                  4  0.924803          8
# 27                  4  0.923709          7
# 0.05

# %%
create_char_exp_accuracy_graph('ERM_char_frequency_experiment_2/word_p_0.10')
# Out:
# ERM_char_frequency_experiment_2/word_p_0.10
# 0.1
# ERM_char_frequency_experiment_2/word_p_0.10/word_p_0.1nlp_random_word_delete_aug_size_2.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# [0.9224013081055829, 0.9225414622751693, 0.922476056996029, 0.9229806120065406, 0.9219247839289886, 0.9222237794907732, 0.9222331231020789, 0.9220555944872694, 0.9225414622751693, 0.9225601494977809]
# ERM_char_frequency_experiment_2/word_p_0.10/word_p_0.1nlp_random_word_delete_aug_size_1.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# [0.9230740481195983, 0.9231768278439617, 0.922149030600327, 0.9219901892081289, 0.9220555944872694, 0.9224854006073347, 0.9227657089465078, 0.923083391730904, 0.9228124270030367, 0.9222798411586078]
# ERM_char_frequency_experiment_2/word_p_0.10/word_p_0.1nlp_random_word_delete_aug_size_3.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# [0.9221957486568558, 0.9225321186638635, 0.9229712683952348, 0.9226535856108385, 0.9228965195047886, 0.9223639336603597, 0.9228591450595656, 0.9219808455968231, 0.922476056996029, 0.9227937397804251]
# ERM_char_frequency_experiment_2/word_p_0.10/word_p_0.1nlp_random_word_delete_aug_size_4.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# [0.9222144358794674, 0.9225414622751693, 0.9220836253211866, 0.921906096706377, 0.921663162812427, 0.9225414622751693, 0.9219808455968231, 0.9222424667133847, 0.9215977575332867, 0.9219247839289886]
# [{'num_char_augmented': '2', 'accuracy': 0.9224013081055829, 'batch_num': 0}, {'num_char_augmented': '2', 'accuracy': 0.9225414622751693, 'batch_num': 1}, {'num_char_augmented': '2', 'accuracy': 0.922476056996029, 'batch_num': 2}, {'num_char_augmented': '2', 'accuracy': 0.9229806120065406, 'batch_num': 3}, {'num_char_augmented': '2', 'accuracy': 0.9219247839289886, 'batch_num': 4}, {'num_char_augmented': '2', 'accuracy': 0.9222237794907732, 'batch_num': 5}, {'num_char_augmented': '2', 'accuracy': 0.9222331231020789, 'batch_num': 6}, {'num_char_augmented': '2', 'accuracy': 0.9220555944872694, 'batch_num': 7}, {'num_char_augmented': '2', 'accuracy': 0.9225414622751693, 'batch_num': 8}, {'num_char_augmented': '2', 'accuracy': 0.9225601494977809, 'batch_num': 9}, {'num_char_augmented': '1', 'accuracy': 0.9230740481195983, 'batch_num': 0}, {'num_char_augmented': '1', 'accuracy': 0.9231768278439617, 'batch_num': 1}, {'num_char_augmented': '1', 'accuracy': 0.922149030600327, 'batch_num': 2}, {'num_char_augmented': '1', 'accuracy': 0.9219901892081289, 'batch_num': 3}, {'num_char_augmented': '1', 'accuracy': 0.9220555944872694, 'batch_num': 4}, {'num_char_augmented': '1', 'accuracy': 0.9224854006073347, 'batch_num': 5}, {'num_char_augmented': '1', 'accuracy': 0.9227657089465078, 'batch_num': 6}, {'num_char_augmented': '1', 'accuracy': 0.923083391730904, 'batch_num': 7}, {'num_char_augmented': '1', 'accuracy': 0.9228124270030367, 'batch_num': 8}, {'num_char_augmented': '1', 'accuracy': 0.9222798411586078, 'batch_num': 9}, {'num_char_augmented': '3', 'accuracy': 0.9221957486568558, 'batch_num': 0}, {'num_char_augmented': '3', 'accuracy': 0.9225321186638635, 'batch_num': 1}, {'num_char_augmented': '3', 'accuracy': 0.9229712683952348, 'batch_num': 2}, {'num_char_augmented': '3', 'accuracy': 0.9226535856108385, 'batch_num': 3}, {'num_char_augmented': '3', 'accuracy': 0.9228965195047886, 'batch_num': 4}, {'num_char_augmented': '3', 'accuracy': 0.9223639336603597, 'batch_num': 5}, {'num_char_augmented': '3', 'accuracy': 0.9228591450595656, 'batch_num': 6}, {'num_char_augmented': '3', 'accuracy': 0.9219808455968231, 'batch_num': 7}, {'num_char_augmented': '3', 'accuracy': 0.922476056996029, 'batch_num': 8}, {'num_char_augmented': '3', 'accuracy': 0.9227937397804251, 'batch_num': 9}, {'num_char_augmented': '4', 'accuracy': 0.9222144358794674, 'batch_num': 0}, {'num_char_augmented': '4', 'accuracy': 0.9225414622751693, 'batch_num': 1}, {'num_char_augmented': '4', 'accuracy': 0.9220836253211866, 'batch_num': 2}, {'num_char_augmented': '4', 'accuracy': 0.921906096706377, 'batch_num': 3}, {'num_char_augmented': '4', 'accuracy': 0.921663162812427, 'batch_num': 4}, {'num_char_augmented': '4', 'accuracy': 0.9225414622751693, 'batch_num': 5}, {'num_char_augmented': '4', 'accuracy': 0.9219808455968231, 'batch_num': 6}, {'num_char_augmented': '4', 'accuracy': 0.9222424667133847, 'batch_num': 7}, {'num_char_augmented': '4', 'accuracy': 0.9215977575332867, 'batch_num': 8}, {'num_char_augmented': '4', 'accuracy': 0.9219247839289886, 'batch_num': 9}]
#    num_char_augmented  accuracy  batch_num
# 19                  1  0.922280          9
# 18                  1  0.922812          8
# 17                  1  0.923083          7
# 16                  1  0.922766          6
# 15                  1  0.922485          5
# 14                  1  0.922056          4
# 13                  1  0.921990          3
# 12                  1  0.922149          2
# 11                  1  0.923177          1
# 10                  1  0.923074          0
# 0                   2  0.922401          0
# 8                   2  0.922541          8
# 7                   2  0.922056          7
# 6                   2  0.922233          6
# 5                   2  0.922224          5
# 4                   2  0.921925          4
# 3                   2  0.922981          3
# 2                   2  0.922476          2
# 1                   2  0.922541          1
# 9                   2  0.922560          9
# 29                  3  0.922794          9
# 28                  3  0.922476          8
# 27                  3  0.921981          7
# 26                  3  0.922859          6
# 25                  3  0.922364          5
# 23                  3  0.922654          3
# 22                  3  0.922971          2
# 21                  3  0.922532          1
# 20                  3  0.922196          0
# 24                  3  0.922897          4
# 38                  4  0.921598          8
# 30                  4  0.922214          0
# 31                  4  0.922541          1
# 32                  4  0.922084          2
# 33                  4  0.921906          3
# 34                  4  0.921663          4
# 35                  4  0.922541          5
# 36                  4  0.921981          6
# 37                  4  0.922242          7
# 39                  4  0.921925          9
# 0.1

# %%
create_char_exp_accuracy_graph('ERM_char_frequency_experiment_2/word_p_0.20')
# Out:
# ERM_char_frequency_experiment_2/word_p_0.20
# 0.2
# ERM_char_frequency_experiment_2/word_p_0.20/word_p_0.2nlp_random_word_delete_aug_size_2.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# [0.9182060266292922, 0.9174118196683018, 0.9179444055127307, 0.9181499649614576, 0.9173277271665499, 0.9175519738378883, 0.9180658724597057, 0.917645409950946, 0.9173931324456902, 0.9175519738378883]
# ERM_char_frequency_experiment_2/word_p_0.20/word_p_0.2nlp_random_word_delete_aug_size_1.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# [0.9179070310675076, 0.9174211632796075, 0.917402476056996, 0.9178603130109787, 0.918093903293623, 0.918215370240598, 0.9182901191310442, 0.9180752160710114, 0.9182620882971269, 0.9179350619014249]
# ERM_char_frequency_experiment_2/word_p_0.20/word_p_0.2nlp_random_word_delete_aug_size_4.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# [0.9180658724597057, 0.9182714319084326, 0.9178416257883673, 0.917486568558748, 0.9186451763606635, 0.9179163746788134, 0.9179257182901192, 0.917281009110021, 0.9176640971735576, 0.9182807755197384]
# ERM_char_frequency_experiment_2/word_p_0.20/word_p_0.2nlp_random_word_delete_aug_size_3.npy
#   0%|          | 0/10 [00:00<?, ?it/s]
# [0.9176734407848633, 0.9172623218874095, 0.9172996963326325, 0.9179724363466479, 0.9171315113291287, 0.9168792338238729, 0.9180004671805653, 0.9177388460640037, 0.9169259518804018, 0.9173744452230788]
# [{'num_char_augmented': '2', 'accuracy': 0.9182060266292922, 'batch_num': 0}, {'num_char_augmented': '2', 'accuracy': 0.9174118196683018, 'batch_num': 1}, {'num_char_augmented': '2', 'accuracy': 0.9179444055127307, 'batch_num': 2}, {'num_char_augmented': '2', 'accuracy': 0.9181499649614576, 'batch_num': 3}, {'num_char_augmented': '2', 'accuracy': 0.9173277271665499, 'batch_num': 4}, {'num_char_augmented': '2', 'accuracy': 0.9175519738378883, 'batch_num': 5}, {'num_char_augmented': '2', 'accuracy': 0.9180658724597057, 'batch_num': 6}, {'num_char_augmented': '2', 'accuracy': 0.917645409950946, 'batch_num': 7}, {'num_char_augmented': '2', 'accuracy': 0.9173931324456902, 'batch_num': 8}, {'num_char_augmented': '2', 'accuracy': 0.9175519738378883, 'batch_num': 9}, {'num_char_augmented': '1', 'accuracy': 0.9179070310675076, 'batch_num': 0}, {'num_char_augmented': '1', 'accuracy': 0.9174211632796075, 'batch_num': 1}, {'num_char_augmented': '1', 'accuracy': 0.917402476056996, 'batch_num': 2}, {'num_char_augmented': '1', 'accuracy': 0.9178603130109787, 'batch_num': 3}, {'num_char_augmented': '1', 'accuracy': 0.918093903293623, 'batch_num': 4}, {'num_char_augmented': '1', 'accuracy': 0.918215370240598, 'batch_num': 5}, {'num_char_augmented': '1', 'accuracy': 0.9182901191310442, 'batch_num': 6}, {'num_char_augmented': '1', 'accuracy': 0.9180752160710114, 'batch_num': 7}, {'num_char_augmented': '1', 'accuracy': 0.9182620882971269, 'batch_num': 8}, {'num_char_augmented': '1', 'accuracy': 0.9179350619014249, 'batch_num': 9}, {'num_char_augmented': '4', 'accuracy': 0.9180658724597057, 'batch_num': 0}, {'num_char_augmented': '4', 'accuracy': 0.9182714319084326, 'batch_num': 1}, {'num_char_augmented': '4', 'accuracy': 0.9178416257883673, 'batch_num': 2}, {'num_char_augmented': '4', 'accuracy': 0.917486568558748, 'batch_num': 3}, {'num_char_augmented': '4', 'accuracy': 0.9186451763606635, 'batch_num': 4}, {'num_char_augmented': '4', 'accuracy': 0.9179163746788134, 'batch_num': 5}, {'num_char_augmented': '4', 'accuracy': 0.9179257182901192, 'batch_num': 6}, {'num_char_augmented': '4', 'accuracy': 0.917281009110021, 'batch_num': 7}, {'num_char_augmented': '4', 'accuracy': 0.9176640971735576, 'batch_num': 8}, {'num_char_augmented': '4', 'accuracy': 0.9182807755197384, 'batch_num': 9}, {'num_char_augmented': '3', 'accuracy': 0.9176734407848633, 'batch_num': 0}, {'num_char_augmented': '3', 'accuracy': 0.9172623218874095, 'batch_num': 1}, {'num_char_augmented': '3', 'accuracy': 0.9172996963326325, 'batch_num': 2}, {'num_char_augmented': '3', 'accuracy': 0.9179724363466479, 'batch_num': 3}, {'num_char_augmented': '3', 'accuracy': 0.9171315113291287, 'batch_num': 4}, {'num_char_augmented': '3', 'accuracy': 0.9168792338238729, 'batch_num': 5}, {'num_char_augmented': '3', 'accuracy': 0.9180004671805653, 'batch_num': 6}, {'num_char_augmented': '3', 'accuracy': 0.9177388460640037, 'batch_num': 7}, {'num_char_augmented': '3', 'accuracy': 0.9169259518804018, 'batch_num': 8}, {'num_char_augmented': '3', 'accuracy': 0.9173744452230788, 'batch_num': 9}]
#    num_char_augmented  accuracy  batch_num
# 19                  1  0.917935          9
# 18                  1  0.918262          8
# 17                  1  0.918075          7
# 16                  1  0.918290          6
# 15                  1  0.918215          5
# 14                  1  0.918094          4
# 13                  1  0.917860          3
# 12                  1  0.917402          2
# 11                  1  0.917421          1
# 10                  1  0.917907          0
# 0                   2  0.918206          0
# 8                   2  0.917393          8
# 7                   2  0.917645          7
# 6                   2  0.918066          6
# 5                   2  0.917552          5
# 4                   2  0.917328          4
# 3                   2  0.918150          3
# 2                   2  0.917944          2
# 1                   2  0.917412          1
# 9                   2  0.917552          9
# 32                  3  0.917300          2
# 33                  3  0.917972          3
# 37                  3  0.917739          7
# 35                  3  0.916879          5
# 36                  3  0.918000          6
# 31                  3  0.917262          1
# 34                  3  0.917132          4
# 30                  3  0.917673          0
# 39                  3  0.917374          9
# 38                  3  0.916926          8
# 29                  4  0.918281          9
# 27                  4  0.917281          7
# 26                  4  0.917926          6
# 24                  4  0.918645          4
# 23                  4  0.917487          3
# 22                  4  0.917842          2
# 21                  4  0.918271          1
# 20                  4  0.918066          0
# 28                  4  0.917664          8
# 25                  4  0.917916          5
# 0.2

# %%
""" 
EXPERIMENT: IMPACT OF WORD AUGMENTATION INTENSITY ON ACCURACY
"""

word_augmentation = 'nlp_random_word_delete'

for i in range(2, 11):
    predict_augmented_labels(word_augmentation, aug_size = i)

# %%
char_augmentation = 'nlp_random_word_delete'

word_percentages = [0.05, 0.1, 0.2, 0.25, 0.5, 0.75]

for word_p in word_percentages:
    for num_char in range(1, 5):
        predict_augmented_labels(transform_name = char_augmentation
                                , num_samples = 1
                                , aug_char_min = num_char
                                , aug_char_max = num_char
                                , aug_char_p = 1
                                , aug_word_min = 1
                                , aug_word_max = None
                                , aug_word_p = word_p
                                , min_char = 4
                                )
# Out:
# num_samples: 1
# char_min: 1
# word_p: 0.05
# char_min: 1
# word_p: 0.05
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 2
# word_p: 0.05
# char_min: 2
# word_p: 0.05
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 3
# word_p: 0.05
# char_min: 3
# word_p: 0.05
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 4
# word_p: 0.05
# char_min: 4
# word_p: 0.05
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 1
# word_p: 0.1
# char_min: 1
# word_p: 0.1
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 2
# word_p: 0.1
# char_min: 2
# word_p: 0.1
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 3
# word_p: 0.1
# char_min: 3
# word_p: 0.1
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 4
# word_p: 0.1
# char_min: 4
# word_p: 0.1
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 1
# word_p: 0.2
# char_min: 1
# word_p: 0.2
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 2
# word_p: 0.2
# char_min: 2
# word_p: 0.2
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 3
# word_p: 0.2
# char_min: 3
# word_p: 0.2
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 4
# word_p: 0.2
# char_min: 4
# word_p: 0.2
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 1
# word_p: 0.25
# char_min: 1
# word_p: 0.25
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 2
# word_p: 0.25
# char_min: 2
# word_p: 0.25
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 3
# word_p: 0.25
# char_min: 3
# word_p: 0.25
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 4
# word_p: 0.25
# char_min: 4
# word_p: 0.25
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 1
# word_p: 0.5
# char_min: 1
# word_p: 0.5
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 2
# word_p: 0.5
# char_min: 2
# word_p: 0.5
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 3
# word_p: 0.5
# char_min: 3
# word_p: 0.5
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 4
# word_p: 0.5
# char_min: 4
# word_p: 0.5
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 1
# word_p: 0.75
# char_min: 1
# word_p: 0.75
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 2
# word_p: 0.75
# char_min: 2
# word_p: 0.75
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 3
# word_p: 0.75
# char_min: 3
# word_p: 0.75
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions
# num_samples: 1
# char_min: 4
# word_p: 0.75
# char_min: 4
# word_p: 0.75
# nlp_random_word_delete
# initialize model
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertClassifier: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertClassifier were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# initialization complete
# generating predictions
#   0%|          | 0/2091 [00:00<?, ?it/s]
# writing predictions

# %%
def create_word_exp_accuracy_graph(exp_folder, graph_type = 'bar'):
    
    aug_to_acc = []
    
    print(exp_folder)

    for filename in os.listdir(exp_folder):
        print(filename)
        full_path = exp_folder + '/' + filename
        #print(full_path)
        if os.path.isfile(full_path):
            accuracies = calculate_accuracy(full_path)
            num_word = filename.split('_')[-1].split('.')[0] # HOW TO GET NUMBER OF CHARACTERS

            for i in range(len(accuracies)):
                accuracy = accuracies[i]
                aug_dict = {"num_word_augmented":int(num_word), "accuracy": accuracy, "batch_num": i}
                aug_to_acc.append(aug_dict)

    
    acc_df = pd.DataFrame(aug_to_acc).sort_values('num_word_augmented', ascending = True)
    print(acc_df)
    
    fig, ax = plt.subplots()

    if graph_type == 'bar':
        p = sns.barplot(x = 'num_word_augmented', y = 'accuracy', data = acc_df, ci = 95, ax = ax)#, order = acc_df['augmentation'])
    
    elif graph_type == 'box':
        p = sns.boxplot(x = 'num_word_augmented', y = 'accuracy', data = acc_df, ax = ax)#, order = acc_df['augmentation'])


    min_value = acc_df.min()['accuracy']
    max_value = acc_df.max()['accuracy']

    ax.set_ylim(min_value - 0.02, min(1.0, max_value + 0.02))
    
    show_values(p)
    plt.rcParams['figure.figsize'] = (30,10)
    
    title = "input modified with nlpaug_random_word_delete"
    
    plt.title(title)
    plt.show()

# %%
create_word_exp_accuracy_graph('ERM_word_frequency_experiment', graph_type = 'box')
